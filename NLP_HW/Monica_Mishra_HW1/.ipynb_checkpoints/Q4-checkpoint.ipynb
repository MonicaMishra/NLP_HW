# %% [markdown]
# ## Q4
# POS Tagging - HMM (50 points)
# The training dataset is a subset of the Brown corpus, where each le contains sentences of
# tokenized words followed by POS tags, and where each line contains one sentence:
# https://www.dropbox.com/sh/havbkrjqzu9kpv6/AABVY0xRUvu-AO2TyftQUwCEa?dl=0
# The test dataset (which is another subset of the Brown corpus, containing tokenized words
# but no tags) is the following:
#
#
# https://www.dropbox.com/s/5j62js3pa0z6z9e/science_sample.txt?dl=0
# Information regarding the categories of the dataset can be found at:
# https://www.dropbox.com/s/ujnz04e62e9603j/CONTENTS.txt?dl=0
# Your task is to implement a part-of-speech tagger using a bigram HMM. Given an ob-
# servation sequence of n words wn
# 1 , choose the most probable sequence of POS tags tn1
# .
#
# [Note: During training, for a word to be counted as unknown, the frequency of word in
# training set should not exceed a threshold (e.g. 5). You can pick a threshold based on your
# algorithm design.]
#
#
# To obtain the tag unigram counts and the tag bigram counts, you will need to separate
# out each tag from its word. For each sentence found in the training data, add a start token
# and an end token to the beginning and the end of the sentence.

# %%
import os
import time
import re
import pickle
import random
import numpy as np
from collections import Counter

# %%
## get dataset and append start and end tag
def data_extractor(dataset):
    complete_data = []
    filename = os.getcwd() + "\\" + dataset 
    for text in os.listdir(filename):
        filename = filename + "\\" + text
        if ".DS_Store" not in filename:
            with open(filename, encoding = "utf8", errors = "ignore") as file:
                text_in_file = file.read()
                text_in_file = re.sub("\n+", "\n", text_in_file)
                text_in_file = re.sub("\t", "", text_in_file)
                text_in_file = text_in_file.split("./.")
                list_words = []
                for i in text_in_file:
                    if i not in ["\n", "", " "]:
                        i = i.strip("\n")
                        list_of_words = "<START> " + i + " <END>"
                        word_list = re.findall("\w+/\w+|\<START\>|\<END\>", list_of_words)
                        list_words.extend(word_list)
            complete_data.extend(list_words)
        filename = os.getcwd() + "\\" + dataset 
    return complete_data
# Out:
# list

# %% [markdown]
# ## 4.1
# Obtain frequency counts from the collection of all the training les (counted together). You
# will need the following types of frequency counts: word-tag counts, tag unigram counts,
# and tag bigram counts. Lets denote these by C (wi ; ti), C (ti), and C (ti􀀀1 ; ti) respectively.
# Report these quantities.

# %%
## find and count all the unigrams
text_in_file = data_extractor(dataset = "brown-copy")
complete_data_list = [i.split("/")[0] for i in text_in_file if "/" in i]
data_unigram_count = Counter(complete_data_list)
data_count_less_than_5 = {i: data_unigram_count[i] for i in data_unigram_count if data_unigram_count[i] < 5}

# %%
## change the less frequent words to "UNK" token, using replace function instead of list manipulation since it is faster
data_text = " ".join(text_in_file)
for index, i in enumerate(data_count_less_than_5):
    word = " " + i + "/"
    data_text = data_text.replace(word , " UNK/")
    if index % 1000 == 0:
        print (index)

# %%
## count of word and tag
data_text_list = data_text.split(" ")
counter_word_tag = Counter(data_text_list)
counter_word_tag
# Out:
# Counter({'<START>': 48577,
#          'The/at': 7187,
#          'Fulton/np': 17,
#          'County/nn': 85,
#          'Grand/jj': 15,
#          'UNK/nn': 14629,
#          'said/vbd': 1697,
#          'Friday/nr': 59,
#          'an/at': 3496,
#          'investigation/nn': 42,
#          'of/in': 35757,
#          's/np': 2594,
#          'recent/jj': 167,
#          'primary/nn': 17,
#          'election/nn': 74,
#          'produced/vbd': 28,
#          'no/at': 1536,
#          'evidence/nn': 199,
#          'that/cs': 6346,
#          'any/dti': 1271,
#          'irregularities/nns': 8,
#          'took/vbd': 418,
#          'place/nn': 470,
#          '<END>': 48577,
#          'jury/nn': 63,
#          'further/rbr': 89,
#          'in/in': 18921,
#          'end/nn': 367,
#          'UNK/nns': 8204,
#          'the/at': 62058,
#          'City/nn': 133,
#          'Executive/jj': 5,
#          'Committee/nn': 88,
#          'which/wdt': 3507,
#          'had/hvd': 4732,
#          'all/jj': 36,
#          'charge/nn': 105,
#          'deserves/vbz': 16,
#          'praise/nn': 13,
#          'and/cc': 27634,
#          'thanks/nns': 27,
#          'Atlanta/np': 35,
#          'for/in': 8376,
#          'manner/nn': 123,
#          'was/bedz': 9579,
#          'conducted/vbn': 41,
#          'October/np': 54,
#          'term/nn': 124,
#          'been/ben': 2430,
#          'charged/vbn': 40,
#          'by/in': 5009,
#          'Superior/jj': 16,
#          'Court/nn': 110,
#          'Judge/nn': 38,
#          'UNK/np': 9197,
#          'to/to': 14550,
#          'investigate/vb': 11,
#          'reports/nns': 64,
#          'possible/jj': 370,
#          'fought/jj': 2,
#          'won/vbn': 22,
#          'Allen/np': 20,
#          'Only/rb': 93,
#          'a/at': 21650,
#          'relative/jj': 43,
#          'handful/nn': 13,
#          'such/jj': 894,
#          'received/vbn': 97,
#          'considering/in': 15,
#          'widespread/jj': 29,
#          'interest/nn': 322,
#          'number/nn': 463,
#          'voters/nns': 18,
#          'size/nn': 139,
#          'this/dt': 3916,
#          'city/nn': 265,
#          'it/pps': 3787,
#          'did/dod': 959,
#          'find/vb': 389,
#          'many/ap': 886,
#          'registration/nn': 23,
#          'laws/nns': 89,
#          'are/ber': 4310,
#          'UNK/jj': 6829,
#          'or/cc': 4090,
#          'inadequate/jj': 32,
#          'often/rb': 346,
#          'ambiguous/jj': 23,
#          'It/pps': 2006,
#          'recommended/vbd': 17,
#          'legislators/nns': 16,
#          'act/vb': 73,
#          'have/hv': 3831,
#          'these/dts': 1216,
#          'studied/vbn': 45,
#          'revised/vbn': 9,
#          'to/in': 10872,
#          'UNK/vbg': 3313,
#          'improving/vbg': 16,
#          'them/ppo': 1728,
#          'grand/jj': 30,
#          'commented/vbd': 16,
#          'on/in': 5760,
#          'other/ap': 1605,
#          'topics/nns': 10,
#          'among/in': 302,
#          'purchasing/vbg': 13,
#          'departments/nns': 25,
#          'well/ql': 69,
#          'operated/vbn': 19,
#          'follow/vb': 88,
#          'generally/rb': 116,
#          'accepted/vbn': 66,
#          'practices/nns': 49,
#          'UNK/vb': 2140,
#          'best/jjt': 284,
#          'both/abx': 641,
#          'governments/nns': 51,
#          'proposed/vbn': 63,
#          'However/wrb': 23,
#          'believes/vbz': 43,
#          'two/cd': 1319,
#          'offices/nns': 39,
#          'should/md': 862,
#          'be/be': 6262,
#          'combined/vbn': 33,
#          'achieve/vb': 51,
#          'greater/jjr': 180,
#          'efficiency/nn': 48,
#          'reduce/vb': 62,
#          'cost/nn': 190,
#          'administration/nn': 103,
#          'Department/nn': 164,
#          'is/bez': 9963,
#          'lacking/vbg': 26,
#          'experienced/vbn': 43,
#          'clerical/jj': 9,
#          'personnel/nns': 66,
#          'as/cs': 5513,
#          'result/nn': 196,
#          'policies/nns': 66,
#          'urged/vbd': 20,
#          'take/vb': 562,
#          'steps/nns': 114,
#          'remedy/vb': 3,
#          'problem/nn': 305,
#          'automobile/nn': 43,
#          'title/nn': 52,
#          'law/nn': 289,
#          'also/rb': 997,
#          'recommended/vbn': 29,
#          'outgoing/jj': 8,
#          'next/ap': 288,
#          'Legislature/nn': 27,
#          'provide/vb': 214,
#          'enabling/vbg': 13,
#          'funds/nns': 90,
#          'set/vb': 88,
#          'effective/jj': 128,
#          'date/nn': 96,
#          'so/cs': 415,
#          'orderly/jj': 19,
#          'implementation/nn': 5,
#          'may/md': 1286,
#          'effected/vbn': 11,
#          'at/in': 4912,
#          'State/nn': 263,
#          'Welfare/nn': 7,
#          's/nn': 1918,
#          'handling/nn': 25,
#          'federal/jj': 112,
#          'granted/vbn': 46,
#          'child/nn': 210,
#          'welfare/nn': 48,
#          'services/nns': 127,
#          'homes/nns': 61,
#          'This/dt': 1167,
#          'one/cd': 2382,
#          'major/jj': 222,
#          'items/nns': 71,
#          'general/jj': 291,
#          'assistance/nn': 85,
#          'program/nn': 366,
#          'but/cc': 2800,
#          'has/hvz': 2415,
#          'seen/vbn': 272,
#          'fit/jj': 8,
#          'distribute/vb': 6,
#          'through/in': 865,
#          'all/abn': 2496,
#          'counties/nns': 31,
#          'state/nn': 537,
#          'with/in': 6940,
#          'exception/nn': 40,
#          'receives/vbz': 20,
#          'none/pn': 88,
#          'money/nn': 260,
#          'they/ppss': 2720,
#          'realize/vb': 69,
#          'proportionate/jj': 9,
#          'distribution/nn': 84,
#          'might/md': 646,
#          'our/pp': 1136,
#          'less/ql': 177,
#          'populous/jj': 5,
#          'Nevertheless/rb': 41,
#          'we/ppss': 1943,
#          'feel/vb': 197,
#          'future/nn': 132,
#          'receive/vb': 76,
#          'some/dti': 1372,
#          'portion/nn': 62,
#          'available/jj': 238,
#          'do/do': 1236,
#          'will/md': 2089,
#          'continue/vb': 105,
#          'place/vb': 53,
#          'burden/nn': 43,
#          'taxpayers/nns': 20,
#          'court/nn': 118,
#          'under/in': 627,
#          'fire/nn': 171,
#          'its/pp': 1767,
#          'appointment/nn': 26,
#          'administrators/nns': 5,
#          'fees/nns': 27,
#          'compensation/nn': 17,
#          'protected/vbn': 26,
#          'found/vbd': 265,
#          'incorporated/vbn': 11,
#          'into/in': 1757,
#          'operating/vbg': 82,
#          'procedures/nns': 61,
#          'recommendations/nns': 21,
#          'previous/jj': 73,
#          'Bar/nn': 11,
#          'Association/nn': 86,
#          'interim/nn': 5,
#          'citizens/nns': 76,
#          'committee/nn': 78,
#          'These/dts': 342,
#          'actions/nns': 66,
#          'serve/vb': 101,
#          'protect/vb': 34,
#          'fact/nn': 442,
#          'effect/nn': 196,
#          'from/in': 4162,
#          'undue/jj': 13,
#          'costs/nns': 160,
#          'appointed/vbn': 34,
#          'elected/vbn': 33,
#          'servants/nns': 22,
#          'criticisms/nns': 11,
#          'UNK/in': 71,
#          'new/jj': 1053,
#          'dollar/jj': 8,
#          'airport/nn': 11,
#          'when/wrb': 1725,
#          'management/nn': 98,
#          'takes/vbz': 84,
#          '1/cd': 574,
#          'that/wps': 1628,
#          'eliminate/vb': 25,
#          'political/jj': 259,
#          'influences/nns': 11,
#          'elaborate/vb': 6,
#          'added/vbd': 81,
#          'there/ex': 1331,
#          'periodic/jj': 8,
#          'surveillance/nn': 6,
#          'pricing/vbg': 5,
#          'concessionaires/nns': 6,
#          'purpose/nn': 145,
#          'keeping/vbg': 53,
#          'prices/nns': 61,
#          'reasonable/jj': 64,
#          'Ask/vb': 12,
#          'jail/nn': 17,
#          'deputies/nns': 13,
#          'On/in': 340,
#          'matters/nns': 58,
#          'Four/cd': 37,
#          'additional/jj': 106,
#          'employed/vbn': 43,
#          'doctor/nn': 87,
#          'medical/jj': 120,
#          'night/nn': 391,
#          'weekend/nn': 27,
#          'duty/nn': 59,
#          '2/cd': 485,
#          'work/vb': 174,
#          'officials/nns': 56,
#          'pass/vb': 62,
#          'legislation/nn': 44,
#          'permit/vb': 65,
#          'establishment/nn': 52,
#          'fair/jj': 60,
#          'equitable/jj': 11,
#          'pension/nn': 12,
#          'plan/nn': 164,
#          'employes/nns': 15,
#          'praised/vbd': 8,
#          'operation/nn': 118,
#          'Police/nns': 20,
#          'Tax/nn': 10,
#          'Office/nn': 41,
#          'prison/nn': 41,
#          'farms/nns': 16,
#          'Grady/np': 5,
#          'Hospital/nn': 35,
#          'Health/nn': 17,
#          'Mayor/nn': 30,
#          'William/np': 147,
#          'Hartsfield/np': 5,
#          'filed/vbd': 11,
#          'suit/nn': 40,
#          'divorce/nn': 19,
#          'his/pp': 6371,
#          'wife/nn': 227,
#          'Pearl/np': 2,
#          'Williams/np': 32,
#          'His/pp': 521,
#          'petition/nn': 14,
#          'charged/vbd': 17,
#          'mental/jj': 39,
#          'cruelty/nn': 13,
#          'couple/nn': 120,
#          'married/vbn': 78,
#          '1913/cd': 12,
#          'They/ppss': 833,
#          'son/nn': 141,
#          'Berry/np': 6,
#          'daughter/nn': 72,
#          'Griffin/np': 6,
#          'mayor/nn': 9,
#          'property/nn': 150,
#          'settlement/nn': 25,
#          'agreed/vbn': 28,
#          'upon/rb': 44,
#          'listed/vbd': 11,
#          'occupation/nn': 23,
#          'attorney/nn': 26,
#          'age/nn': 214,
#          '71/cd': 10,
#          '74/cd': 6,
#          'birth/nn': 63,
#          'lived/vbn': 41,
#          'together/rb': 259,
#          'man/nn': 1131,
#          'more/ap': 933,
#          'than/in': 495,
#          'year/nn': 648,
#          'home/nr': 300,
#          'UNK/cd': 928,
#          'Pelham/np': 5,
#          'Aj/nn': 107,
#          'Henry/np': 84,
#          'listed/vbn': 31,
#          'brief/jj': 62,
#          'since/in': 148,
#          '1937/cd': 10,
#          'career/nn': 67,
#          'goes/vbz': 87,
#          'back/rb': 705,
#          'council/nn': 27,
#          '1923/cd': 7,
#          'present/jj': 225,
#          'office/nn': 215,
#          'UNK/vbz': 1152,
#          'He/pps': 2930,
#          'succeeded/vbn': 14,
#          'who/wps': 2178,
#          'became/vbd': 243,
#          'candidate/nn': 32,
#          '13/cd': 53,
#          'after/cs': 266,
#          'announced/vbd': 51,
#          'he/pps': 6425,
#          'would/md': 2598,
#          'run/vb': 119,
#          'Georgia/np': 46,
#          'Republicans/nps': 29,
#          'getting/vbg': 152,
#          'strong/jj': 187,
#          'encouragement/nn': 14,
#          'enter/vb': 83,
#          '1962/cd': 35,
#          'race/nn': 95,
#          'top/jjs': 67,
#          'official/nn': 20,
#          'Wednesday/nr': 35,
#          'Robert/np': 82,
#          'GOP/nn': 13,
#          'chairman/nn': 49,
#          'meeting/nn': 123,
#          'held/vbn': 133,
#          'Tuesday/nr': 58,
#          'Blue/jj': 44,
#          'Ridge/nn': 6,
#          'brought/vbd': 134,
#          'enthusiastic/jj': 24,
#          'responses/nns': 26,
#          'audience/nn': 114,
#          'Party/nn': 21,
#          'Chairman/nn': 19,
#          'James/np': 101,
#          'enthusiasm/nn': 27,
#          'picking/vbg': 13,
#          'up/rp': 1666,
#          'rally/nn': 5,
#          '8/cd': 127,
#          'Savannah/np': 9,
#          'newly/rb': 25,
#          'Texas/np': 69,
#          'John/np': 359,
#          'featured/vbn': 5,
#          'speaker/nn': 24,
#          'In/in': 1788,
#          'warned/vbn': 8,
#          'entering/vbg': 24,
#          'governor/nn': 46,
#          'force/vb': 24,
#          'it/ppo': 2806,
#          'petitions/nns': 6,
#          'out/rp': 1595,
#          'voting/vbg': 21,
#          'precincts/nns': 5,
#          'obtain/vb': 42,
#          'signatures/nns': 5,
#          'registered/vbn': 15,
#          'Despite/in': 38,
#          'warning/vbg': 26,
#          'unanimous/jj': 5,
#          'vote/nn': 49,
#          'according/in': 99,
#          'attended/vbd': 24,
#          'When/wrb': 578,
#          'crowd/nn': 48,
#          'asked/vbn': 84,
#          'whether/cs': 255,
#          'wanted/vbd': 203,
#          'wait/vb': 65,
#          'make/vb': 751,
#          'voted/vbd': 22,
#          'no/rb': 68,
#          'were/bed': 3220,
#          'largest/jjt': 53,
#          'face/vb': 51,
#          'says/vbz': 193,
#          'before/cs': 396,
#          'making/vbg': 228,
#          'first/od': 939,
#          'alternative/jj': 9,
#          'courses/nns': 57,
#          'must/md': 990,
#          'taken/vbn': 278,
#          'Five/cd': 44,
#          'per/in': 369,
#          'cent/nn': 156,
#          'each/dt': 747,
#          'county/nn': 70,
#          'sign/vb': 18,
#          'requesting/vbg': 8,
#          'allowed/vbn': 65,
#          'names/nns': 89,
#          'candidates/nns': 38,
#          'ballot/nn': 12,
#          'hold/vb': 134,
#          'unit/nn': 93,
#          'system/nn': 391,
#          'party/nn': 192,
#          'platform/nn': 70,
#          'Sam/np': 79,
#          'Highway/nn': 8,
#          'public/jj': 266,
#          'relations/nns': 93,
#          'director/nn': 77,
#          'resigned/vbd': 7,
#          'Garland/np': 8,
#          'campaign/nn': 74,
#          'resignation/nn': 7,
#          'expected/vbn': 156,
#          'time/nn': 1539,
#          'Rob/np': 17,
#          'assistant/nn': 17,
#          'three/cd': 564,
#          'years/nns': 926,
#          'gubernatorial/jj': 7,
#          'starts/vbz': 21,
#          'become/vb': 233,
#          'coordinator/nn': 5,
#          'Byrd/np': 10,
#          'wind/vb': 7,
#          '1961/cd': 135,
#          'session/nn': 79,
#          'Monday/nr': 68,
#          'head/vb': 13,
#          'where/wrb': 840,
#          'highway/nn': 32,
#          'bond/nn': 43,
#          'approved/vbd': 11,
#          'shortly/rb': 24,
#          'Before/in': 22,
#          'afternoon/nn': 105,
#          'Senate/nn': 57,
#          'approve/vb': 14,
#          'study/nn': 201,
#          'allotted/vbn': 8,
#          'rural/jj': 46,
#          'urban/jj': 41,
#          'areas/nns': 235,
#          'determine/vb': 91,
#          'what/wdt': 1408,
#          'adjustments/nns': 20,
#          'made/vbn': 649,
#          'Vandiver/np': 6,
#          'traditional/jj': 77,
#          'visit/nn': 59,
#          'chambers/nns': 8,
#          'toward/in': 374,
#          'likely/rb': 25,
#          'mention/vb': 33,
#          '100/nns': 12,
#          'million/cd': 204,
#          'issue/nn': 131,
#          'approved/vbn': 26,
#          'earlier/rbr': 67,
#          'priority/nn': 19,
#          'item/nn': 55,
#          'Construction/nn': 6,
#          'bonds/nns': 47,
#          'Meanwhile/rb': 21,
#          'learned/vbn': 56,
#          'very/ql': 669,
#          'near/rb': 20,
#          'being/beg': 655,
#          'ready/jj': 136,
#          'issue/vb': 14,
#          '30/nns': 3,
#          'worth/nn': 19,
#          'reconstruction/nn': 8,
#          'go/vb': 599,
#          'courts/nns': 44,
#          'friendly/jj': 60,
#          'test/nn': 95,
#          'test/vb': 17,
#          'validity/nn': 15,
#          'act/nn': 94,
#          'then/rb': 997,
#          'sales/nns': 125,
#          'begin/vb': 82,
#          'contracts/nns': 20,
#          'let/vbn': 4,
#          'repair/nn': 15,
#          'work/nn': 574,
#          'most/ql': 635,
#          'heavily/rb': 53,
#          'traveled/vbn': 9,
#          'highways/nns': 14,
#          'A/at': 1185,
#          'source/nn': 89,
#          'there/rb': 517,
#          '3/nns': 5,
#          '4/nns': 7,
#          'Rural/jj': 8,
#          'Authority/nn': 10,
#          'road/nn': 186,
#          'construction/nn': 87,
#          'revolving/vbg': 6,
#          'fund/nn': 43,
#          'department/nn': 60,
#          'apparently/rb': 101,
#          'intends/vbz': 6,
#          'issued/vbn': 30,
#          'every/at': 430,
#          'old/jj': 625,
#          'ones/nns': 112,
#          'paid/vbn': 94,
#          'off/rp': 469,
#          'tax/nn': 186,
#          'authorities/nns': 35,
#          'opened/vbd': 92,
#          '1958/cd': 94,
#          'battle/nn': 75,
#          'against/in': 612,
#          'issuance/nn': 7,
#          '50/nns': 23,
#          'roads/nns': 55,
#          'Marvin/np': 9,
#          'told/vbd': 284,
#          'Constitution/nn': 38,
#          'however/wrb': 87,
#          'consulted/vbn': 11,
#          'yet/rb': 216,
#          'about/in': 1219,
#          'plans/nns': 95,
#          'offer/vb': 67,
#          'resolution/nn': 63,
#          'House/nn': 189,
#          'action/nn': 295,
#          'itself/ppl': 300,
#          '10/nns': 8,
#          'day/nn': 621,
#          'increase/nn': 112,
#          'expense/nn': 49,
#          'allowances/nns': 25,
#          'Sunday/nr': 100,
#          'research/nn': 132,
#          'done/vbn': 309,
#          'can/md': 1712,
#          'UNK/vbn': 2879,
#          'outright/rb': 4,
#          'notice/nn': 29,
#          'first/rb': 292,
#          'given/vbn': 366,
#          'sought/vbn': 20,
#          'While/cs': 120,
#          'technical/jj': 113,
#          'details/nns': 56,
#          'fully/rb': 66,
#          'worked/vbn': 52,
#          'seek/vb': 69,
#          'aside/rb': 56,
#          'privilege/nn': 18,
#          '31/cd': 41,
#          'similar/jj': 145,
#          'passed/vbd': 91,
#          '5/cd': 199,
#          'As/in': 25,
#          'word/nn': 257,
#          'offered/vbn': 40,
#          'pointed/vbd': 46,
#          'last/ap': 568,
#          'November/np': 73,
#          'rejected/vbd': 12,
#          'constitutional/jj': 24,
#          'amendment/nn': 17,
#          'allow/vb': 70,
#          'vote/vb': 26,
#          'pay/nn': 38,
#          'raises/nns': 3,
#          'future/jj': 80,
#          'sessions/nns': 27,
#          'veteran/jj': 8,
#          'Jackson/np': 36,
#          'legislator/nn': 7,
#          'ask/vb': 110,
#          'back/vb': 25,
#          'aid/nn': 109,
#          'education/nn': 177,
#          'something/pn': 412,
#          'consistently/rb': 19,
#          'opposed/vbn': 32,
#          'past/nn': 97,
#          'Barber/np': 4,
#          'Commerce/nn': 40,
#          'asking/vbg': 65,
#          'endorse/vb': 6,
#          'increased/vbn': 103,
#          'support/nn': 123,
#          'provided/vbn': 99,
#          'expended/vbn': 10,
#          '13th/od': 6,
#          'members/nns': 309,
#          'congressional/jj': 13,
#          'delegation/nn': 11,
#          'Washington/np': 206,
#          'like/vb': 207,
#          'see/vb': 712,
#          'passed/vbn': 67,
#          'But/cc': 1337,
#          'congressmen/nns': 8,
#          'specifically/rb': 35,
#          'asked/vbd': 289,
#          'him/ppo': 2518,
#          'tossed/vbd': 22,
#          'formally/rb': 17,
#          'read/vbn': 45,
#          'event/nn': 80,
#          'Congress/np': 150,
#          'does/doz': 442,
#          'Board/nn': 69,
#          'Education/nn': 39,
#          'directed/vbn': 55,
#          'give/vb': 370,
#          'teacher/nn': 79,
#          'After/in': 155,
#          'long/jj': 502,
#          'hot/jj': 117,
#          'controversy/nn': 26,
#          'Miller/np': 22,
#          'school/nn': 427,
#          'superintendent/nn': 13,
#          'policeman/nn': 18,
#          'put/vbd': 130,
#          'UNK/jjt': 202,
#          'I/ppss': 5057,
#          'ever/rb': 318,
#          'saw/vbd': 329,
#          'Harry/np': 34,
#          'Davis/np': 27,
#          'agriculture/nn': 12,
#          'defeated/vbd': 5,
#          'Felix/np': 30,
#          'principal/nn': 19,
#          'Democratic/jj': 68,
#          'received/vbd': 64,
#          'votes/nns': 17,
#          's/nr': 77,
#          'got/vbd': 327,
#          'Ordinary/nn': 2,
#          'Carey/np': 5,
#          'armed/vbn': 31,
#          'pistol/nn': 27,
#          'stood/vbd': 193,
#          'polls/nns': 9,
#          'insure/vb': 24,
#          'order/nn': 345,
#          'Tom/np': 63,
#          'Being/beg': 17,
#          'just/rb': 658,
#          'like/cs': 939,
#          'church/nn': 221,
#          't/dod': 396,
#          'smell/vb': 9,
#          'drop/nn': 24,
#          'liquor/nn': 44,
#          'bit/nn': 93,
#          'trouble/nn': 124,
#          'leading/vbg': 65,
#          'so/ql': 877,
#          'quiet/jj': 62,
#          'marked/vbn': 68,
#          'anonymous/jj': 17,
#          'midnight/nn': 20,
#          'phone/nn': 47,
#          'calls/nns': 22,
#          'veiled/vbn': 6,
#          'threats/nns': 14,
#          'violence/nn': 46,
#          'former/ap': 128,
#          'George/np': 129,
#          'shot/vbd': 18,
#          'himself/ppl': 582,
#          'death/nn': 263,
#          'March/np': 92,
#          '18/cd': 58,
#          'four/cd': 355,
#          'days/nns': 373,
#          'post/nn': 58,
#          'dispute/nn': 30,
#          'board/nn': 163,
#          'During/in': 132,
#          'reportedly/rb': 9,
#          'telephone/nn': 63,
#          'too/rb': 277,
#          'subjected/vbn': 24,
#          'soon/rb': 174,
#          'scheduled/vbd': 2,
#          'Many/ap': 99,
#          'local/jj': 268,
#          'feared/vbd': 10,
#          'permit/nn': 10,
#          'carry/vb': 85,
#          'gun/nn': 99,
#          'promised/vbd': 25,
#          'Sheriff/nn': 5,
#          'ordinary/nn': 1,
#          'made/vbd': 458,
#          'good/jj': 681,
#          'promise/nn': 36,
#          'Everything/pn': 23,
#          'went/vbd': 496,
#          'real/ql': 14,
#          'smooth/jj': 36,
#          'sheriff/nn': 15,
#          'There/ex': 796,
#          't/bedz': 150,
#          'Austin/np': 18,
#          'approval/nn': 51,
#          'Price/np': 4,
#          'abandoned/vbn': 20,
#          'seemed/vbd': 307,
#          'certain/jj': 214,
#          'Thursday/nr': 33,
#          'despite/in': 65,
#          'adamant/jj': 5,
#          'protests/nns': 6,
#          'bankers/nns': 11,
#          'Daniel/np': 15,
#          'personally/rb': 35,
#          'led/vbd': 81,
#          'fight/nn': 56,
#          'measure/nn': 60,
#          'watered/vbn': 3,
#          'down/rp': 683,
#          'considerably/rb': 21,
#          'rejection/nn': 12,
#          'hearing/nn': 48,
#          'before/in': 381,
#          'Revenue/nn': 16,
#          'Under/in': 56,
#          'rules/nns': 73,
#          'automatically/rb': 33,
#          'week/nn': 258,
#          'questions/nns': 131,
#          'UNK/vbd': 1573,
#          'appearing/vbg': 16,
#          'witnesses/nns': 19,
#          'left/vbd': 154,
#          'little/ap': 382,
#          'doubt/nn': 95,
#          'recommend/vb': 24,
#          'passage/nn': 48,
#          'termed/vbd': 3,
#          'extremely/rb': 2,
#          'conservative/jj': 30,
#          'estimate/nn': 25,
#          'produce/vb': 74,
#          '17/cd': 45,
#          'dollars/nns': 97,
#          'help/vb': 202,
#          'anticipated/vbn': 18,
#          'deficit/nn': 12,
#          '63/cd': 6,
#          'current/jj': 82,
#          'fiscal/jj': 116,
#          'merely/rb': 127,
#          'means/nns': 112,
#          'books/nns': 93,
#          'republic/nn': 8,
#          'permits/vbz': 25,
#          'over/rp': 376,
#          'bank/nn': 54,
#          'accounts/nns': 27,
#          'stocks/nns': 17,
#          'personal/jj': 192,
#          'persons/nns': 117,
#          'missing/vbg': 31,
#          'seven/cd': 101,
#          'bill/nn': 78,
#          'banks/nns': 19,
#          'insurance/nn': 42,
#          'firms/nns': 55,
#          'companies/nns': 86,
#          'corporations/nns': 21,
#          'report/vb': 37,
#          'treasurer/nn': 15,
#          'cannot/md': 257,
#          'enforced/vbn': 19,
#          'now/rb': 1026,
#          'because/cs': 657,
#          'almost/rb': 249,
#          'impossible/jj': 81,
#          'locate/vb': 14,
#          'declared/vbd': 53,
#          'Lawrence/np': 39,
#          'lawyer/nn': 43,
#          'representing/vbg': 28,
#          'sounded/vbd': 28,
#          'opposition/nn': 45,
#          'violate/vb': 7,
#          'their/pp': 2521,
#          'contractual/jj': 7,
#          'obligations/nns': 21,
#          'undermine/vb': 8,
#          'confidence/nn': 59,
#          'customers/nns': 39,
#          'If/cs': 719,
#          'you/ppss': 1818,
#          'destroy/vb': 48,
#          'economy/nn': 75,
#          'You/ppss': 503,
#          'circulation/nn': 16,
#          'millions/nns': 48,
#          'Charles/np': 96,
#          'Hughes/np': 30,
#          'Sherman/np': 29,
#          'sponsor/nn': 8,
#          'failure/nn': 85,
#          'enact/vb': 7,
#          'amount/vb': 28,
#          'gift/nn': 33,
#          'pockets/nns': 18,
#          'contention/nn': 9,
#          'denied/vbn': 37,
#          'several/ap': 332,
#          'including/in': 165,
#          'Scott/np': 16,
#          'Hudson/np': 52,
#          'Jones/np': 73,
#          'Houston/np': 25,
#          'Howard/np': 32,
#          'Cox/np': 5,
#          'argued/vbd': 17,
#          'probably/rb': 234,
#          'since/cs': 273,
#          'complained/vbd': 21,
#          'enough/ap': 173,
#          'introduced/vbn': 37,
#          'only/rb': 1247,
#          'Senators/nns': 5,
#          'unanimously/rb': 10,
#          'Parkhouse/np': 5,
#          'Dallas/np': 60,
#          'authorizing/vbg': 5,
#          'schools/nns': 190,
#          'deaf/jj': 11,
#          'designed/vbn': 97,
#          'special/jj': 229,
#          'schooling/nn': 3,
#          'students/nns': 203,
#          'scholastic/jj': 9,
#          'reduced/vbn': 67,
#          'debate/nn': 26,
#          'authorize/vb': 5,
#          'Agency/nn': 8,
#          'establish/vb': 59,
#          'wide/jj': 143,
#          '000/cd': 220,
#          'population/nn': 136,
#          'require/vb': 84,
#          'children/nns': 339,
#          'between/in': 705,
#          '6/cd': 138,
#          'attend/vb': 54,
#          'permitting/vbg': 9,
#          'older/jjr': 91,
#          'residential/jj': 41,
#          'School/nn': 74,
#          'here/rb': 595,
#          'Operating/vbg': 6,
#          'budget/nn': 56,
#          'five/cd': 302,
#          'Harris/np': 29,
#          'El/np': 18,
#          'Paso/np': 10,
#          '500/nns': 25,
#          'savings/nns': 17,
#          'yearly/rb': 6,
#          'after/in': 535,
#          'capital/nn': 78,
#          '000/nns': 153,
#          'absorbed/vbn': 22,
#          'estimated/vbd': 8,
#          'saving/vbg': 18,
#          'coming/vbg': 159,
#          'live/vb': 148,
#          'get/vb': 707,
#          'hear/vb': 149,
#          'horse/nn': 113,
#          'Red/np': 21,
#          'Joe/np': 55,
#          'still/rb': 667,
#          'expects/vbz': 22,
#          'tell/vb': 237,
#          'folks/nns': 18,
#          'why/wrb': 238,
#          'thinks/vbz': 23,
#          'rejected/vbn': 20,
#          're/ppss': 275,
#          'pro/jj': 4,
#          'letters/nns': 110,
#          'con/jj': 2,
#          'believe/vb': 193,
#          'if/cs': 1449,
#          'people/nns': 790,
#          'better/rbr': 155,
#          'informed/vbn': 32,
#          'question/nn': 230,
#          'most/ap': 378,
#          'oppose/vb': 15,
#          'm/ppss': 257,
#          'willing/jj': 69,
#          'stake/vb': 1,
#          'my/pp': 1131,
#          'San/np': 70,
#          'Antonio/np': 6,
#          'ponies/nns': 6,
#          'heard/vbd': 126,
#          'option/nn': 5,
#          'proposal/nn': 40,
#          'favorable/jj': 33,
#          'report/nn': 115,
#          'although/cs': 195,
#          'faces/vbz': 12,
#          'hard/jj': 138,
#          'later/rbr': 298,
#          'house/nn': 397,
#          'finally/rb': 131,
#          'sent/vbd': 68,
#          'extending/vbg': 28,
#          'authority/nn': 83,
#          'planning/vbg': 71,
#          'cities/nns': 106,
#          'senate/nn': 5,
#          'quickly/rb': 87,
#          'whipped/vbd': 7,
#          'meager/jj': 5,
#          'fare/nn': 7,
#          ...})

# %%
## count of only tags
tag_list = [i if i in ["<START>", "<END>"] else i.split("/")[1] for i in data_text_list]
counter_tag = Counter(tag_list)
counter_tag
# Out:
# Counter({'1': 1,
#          '16': 9,
#          '2': 62,
#          '20th': 1,
#          '29': 1,
#          '3': 6,
#          '32': 1,
#          '4': 29,
#          '50th': 1,
#          '64': 3,
#          '7': 1,
#          '7074': 4,
#          '8': 16,
#          '9': 1,
#          '<END>': 48577,
#          '<START>': 48577,
#          'Output': 4,
#          'abl': 353,
#          'abn': 2957,
#          'abx': 728,
#          'active': 1,
#          'ap': 9476,
#          'at': 98031,
#          'be': 6294,
#          'bed': 3247,
#          'bedz': 9765,
#          'beg': 675,
#          'bem': 230,
#          'ben': 2432,
#          'ber': 4420,
#          'bez': 10169,
#          'c': 3,
#          'cc': 37546,
#          'cd': 14698,
#          'cell': 1,
#          'chamber': 1,
#          'coating': 1,
#          'cs': 21904,
#          'cwt': 1,
#          'day': 4,
#          'destination': 1,
#          'do': 1814,
#          'dod': 1408,
#          'doz': 569,
#          'dt': 9045,
#          'dti': 2890,
#          'dts': 2417,
#          'dtx': 100,
#          'ex': 2236,
#          'ft': 1,
#          'fw': 1208,
#          'g': 1,
#          'hp': 1,
#          'hr': 1,
#          'hv': 3928,
#          'hvd': 4860,
#          'hvg': 278,
#          'hvn': 229,
#          'hvz': 2452,
#          'in': 121244,
#          'jj': 67754,
#          'jjr': 1970,
#          'jjs': 379,
#          'jjt': 1008,
#          'l': 12,
#          'lBOD': 1,
#          'mbf': 4,
#          'md': 13135,
#          'nil': 116,
#          'nn': 166709,
#          'nns': 57377,
#          'np': 37549,
#          'nps': 1329,
#          'nr': 1967,
#          'nrs': 17,
#          'od': 2118,
#          'or': 17,
#          'output': 1,
#          'pn': 2631,
#          'pp': 16817,
#          'ppl': 1211,
#          'ppls': 342,
#          'ppo': 10956,
#          'pps': 18648,
#          'ppss': 14914,
#          'ql': 8642,
#          'qlp': 252,
#          'rb': 35830,
#          'rbr': 1163,
#          'rbt': 100,
#          'rn': 9,
#          'rp': 5936,
#          'sec': 3,
#          'to': 14805,
#          'uh': 596,
#          'under': 3,
#          'vb': 33534,
#          'vbd': 25661,
#          'vbg': 17882,
#          'vbn': 29590,
#          'vbz': 7443,
#          'watt': 1,
#          'wdt': 5552,
#          'wp': 249,
#          'wpo': 283,
#          'wps': 3952,
#          'wql': 181,
#          'wrb': 4512})

# %%
# count of bigrams tag
bigram_tag_list = [" ".join(tag_list[index:index + 2]) for index in range(len(tag_list[:-1]))]
bigram_counter_tag = Counter(bigram_tag_list)
bigram_counter_tag
# Out:
# Counter({'<START> at': 7616,
#          'at np': 3024,
#          'np nn': 4888,
#          'nn jj': 2257,
#          'jj nn': 31102,
#          'nn vbd': 4399,
#          'vbd nr': 113,
#          'nr at': 89,
#          'at nn': 52459,
#          'nn in': 46270,
#          'in np': 8512,
#          'np jj': 843,
#          'nn nn': 17363,
#          'vbd at': 3962,
#          'nn cs': 4600,
#          'cs dti': 224,
#          'dti nns': 378,
#          'nns vbd': 1669,
#          'vbd nn': 608,
#          'nn <END>': 20572,
#          '<END> <START>': 48576,
#          'nn rbr': 126,
#          'rbr vbd': 50,
#          'vbd in': 4430,
#          'in nn': 18750,
#          'nn nns': 7233,
#          'nns cs': 1500,
#          'cs at': 5683,
#          'nn wdt': 1481,
#          'wdt hvd': 138,
#          'hvd jj': 58,
#          'in at': 43540,
#          'nn vbz': 2481,
#          'vbz at': 1459,
#          'nn cc': 13828,
#          'cc nns': 2095,
#          'nns in': 15649,
#          'np in': 2431,
#          'in wdt': 1429,
#          'wdt at': 483,
#          'nn bedz': 2983,
#          'bedz vbn': 2243,
#          'vbn <END>': 1854,
#          'nn hvd': 827,
#          'hvd ben': 770,
#          'ben vbn': 1119,
#          'vbn in': 10610,
#          'nn np': 3374,
#          'np np': 7372,
#          'np to': 285,
#          'to vb': 12264,
#          'vb nns': 904,
#          'in jj': 8897,
#          'jj nns': 12695,
#          'at jj': 21153,
#          'wdt bedz': 229,
#          'np <END>': 2802,
#          '<START> rb': 3686,
#          'rb at': 2705,
#          'nns bedz': 274,
#          'vbn at': 1517,
#          'nn at': 4112,
#          'in nns': 5720,
#          'nns cc': 6125,
#          'cc at': 4035,
#          'in dt': 3266,
#          'dt nn': 4523,
#          'vbd pps': 440,
#          'pps dod': 402,
#          'dod vb': 757,
#          'vb cs': 1468,
#          'cs ap': 223,
#          'ap in': 1237,
#          'cc nn': 4672,
#          'nns ber': 1672,
#          'ber jj': 696,
#          'jj cc': 3514,
#          'cc jj': 3563,
#          'cc rb': 2556,
#          'rb jj': 1638,
#          'jj <END>': 2498,
#          '<START> pps': 5573,
#          'pps vbd': 6070,
#          'vbd cs': 1162,
#          'cs np': 1299,
#          'np nns': 1034,
#          'nns vb': 1748,
#          'vb to': 1213,
#          'to hv': 334,
#          'hv dts': 8,
#          'dts nns': 1187,
#          'nns vbn': 1402,
#          'vbn cc': 1278,
#          'cc vbn': 1045,
#          'in vbg': 3838,
#          'vbg cc': 621,
#          'cc vbg': 1086,
#          'vbg ppo': 650,
#          'ppo <END>': 1992,
#          'in ap': 1526,
#          'ap nns': 2377,
#          'in ppo': 3927,
#          'ppo at': 569,
#          'np cc': 2781,
#          'cc np': 2175,
#          'nn vbg': 2128,
#          'vbg nns': 1630,
#          'nns wdt': 700,
#          'wdt pps': 539,
#          'vbd ber': 7,
#          'ber ql': 275,
#          'ql vbn': 524,
#          'cc vb': 1581,
#          'vb rb': 1594,
#          'rb vbn': 3118,
#          'vbn nns': 1807,
#          'wdt vb': 184,
#          'vb in': 4900,
#          'at jjt': 679,
#          'jjt nn': 435,
#          'in abx': 228,
#          'abx nns': 185,
#          'nns <END>': 7671,
#          '<START> nn': 1979,
#          'nn vbn': 2265,
#          'vbn wrb': 120,
#          'wrb at': 831,
#          'pps vbz': 1363,
#          'vbz dts': 23,
#          'dts cd': 76,
#          'cd nns': 3586,
#          'nns md': 1423,
#          'md be': 3654,
#          'be vbn': 3052,
#          'vbn to': 1550,
#          'vb jjr': 66,
#          'jjr nn': 705,
#          'vb at': 6151,
#          'vbg nn': 3000,
#          'vbd bez': 21,
#          'bez vbg': 389,
#          'vbg in': 2965,
#          'in vbn': 660,
#          'vbn jj': 909,
#          'nns nns': 915,
#          'nn vb': 1120,
#          'nns to': 1027,
#          'vb dt': 558,
#          'bedz rb': 1186,
#          'at ap': 2987,
#          'ap nn': 2746,
#          'vb vbg': 301,
#          'cs cs': 727,
#          'nn md': 3333,
#          '<START> dt': 1659,
#          'dt bez': 622,
#          'bez cd': 158,
#          'cd in': 2070,
#          'vbd cc': 597,
#          'nn hvz': 926,
#          'hvz vbn': 966,
#          'jj to': 1308,
#          'vb dts': 147,
#          'in abn': 1057,
#          'abn at': 534,
#          'at nns': 7587,
#          'wdt vbz': 382,
#          'vbz pn': 46,
#          'pn in': 495,
#          'vbd ppss': 277,
#          'ppss vb': 3466,
#          'in dts': 1047,
#          'md vb': 5973,
#          'in pp': 7635,
#          'pp ql': 82,
#          'ql jj': 4372,
#          'rb ppss': 853,
#          'cs in': 874,
#          'vb dti': 290,
#          'dti nn': 1171,
#          'dts jj': 252,
#          'nns at': 1416,
#          'vbd <END>': 1373,
#          'nn to': 2862,
#          'to do': 386,
#          'do dt': 57,
#          'dt md': 214,
#          'nn rb': 3983,
#          'rb vbd': 1796,
#          'wdt hvz': 83,
#          'hvz ben': 598,
#          'ben in': 163,
#          'pp nns': 3250,
#          '<START> nns': 1043,
#          'pp vbg': 240,
#          'in cd': 4161,
#          'cd jj': 789,
#          'jj jj': 4429,
#          'nns nn': 1262,
#          '<START> dts': 400,
#          'cc in': 2226,
#          'cc pp': 902,
#          'pp vbn': 179,
#          '<START> in': 4467,
#          'cs wrb': 80,
#          'vbz nn': 371,
#          'nn cd': 1401,
#          'cd at': 413,
#          'nn be': 163,
#          'nn wps': 1548,
#          'wps md': 407,
#          'vb jj': 1393,
#          'nn dod': 143,
#          'vb cc': 831,
#          'cc pps': 1456,
#          'cs ex': 297,
#          'ex md': 198,
#          'be jj': 942,
#          'at vbg': 1618,
#          'vbg at': 2525,
#          'nns jj': 981,
#          '<START> vb': 949,
#          'vb nn': 1626,
#          'cs cd': 249,
#          'cd cd': 807,
#          'nns be': 58,
#          '<START> cd': 962,
#          'cd np': 416,
#          'nns np': 564,
#          'np vbd': 3959,
#          'pp nn': 8888,
#          'nn nr': 213,
#          'nr <END>': 310,
#          '<START> pp': 983,
#          'vbd jj': 702,
#          'vbn cd': 187,
#          'cd <END>': 1504,
#          '<START> ppss': 3814,
#          'ppss hv': 847,
#          'hv at': 523,
#          'vbn rb': 1469,
#          'rb <END>': 2749,
#          'cs nn': 1142,
#          'vbd pp': 1241,
#          'cd cc': 880,
#          'rb cs': 2118,
#          'np nr': 46,
#          'nr bez': 44,
#          'bez in': 512,
#          '<START> np': 3803,
#          'np bedz': 1062,
#          'np hvz': 319,
#          'ben nn': 24,
#          'pp jj': 3077,
#          'vbz rb': 416,
#          'rb in': 5788,
#          'vbz cd': 83,
#          'pps md': 2166,
#          'np wps': 396,
#          'wps vbd': 959,
#          'at cd': 1017,
#          'cd nn': 1826,
#          'cs pps': 3036,
#          'np nps': 71,
#          'nps ber': 45,
#          'ber vbg': 310,
#          'vbg jj': 740,
#          'at jjs': 207,
#          'jjs nn': 223,
#          'vbn nr': 74,
#          'nr nn': 283,
#          'bedz vbg': 843,
#          'vbg rp': 558,
#          'rp in': 2040,
#          'to be': 1695,
#          'wdt rb': 176,
#          'vbn np': 414,
#          'np md': 686,
#          'be at': 614,
#          'at vbn': 1906,
#          'vbn nn': 2489,
#          'vbn cs': 1320,
#          'cs vbg': 445,
#          'vb ppo': 3041,
#          'ppo to': 544,
#          'nns rp': 142,
#          'vbg ex': 9,
#          'ex bedz': 560,
#          'bedz at': 1633,
#          'in in': 1378,
#          'in nps': 107,
#          'nps wps': 53,
#          '<START> wrb': 865,
#          'vbd to': 1223,
#          'vb cd': 357,
#          'cd ap': 142,
#          'nn pps': 2250,
#          'vbd rb': 1891,
#          'rb cc': 1374,
#          'cc ex': 221,
#          'ex bed': 222,
#          'bed at': 191,
#          'at nps': 588,
#          'nps md': 44,
#          'md hv': 1058,
#          'hv to': 262,
#          'vb bez': 65,
#          'bez at': 2103,
#          'vbz cs': 450,
#          'at od': 1346,
#          'od nn': 1300,
#          'nns vbg': 1117,
#          'vbg cs': 368,
#          'nps be': 1,
#          'cc cd': 750,
#          'vbz in': 1371,
#          'nr to': 38,
#          'in dti': 1095,
#          'wps hvz': 133,
#          'ben at': 233,
#          'nn ap': 309,
#          'vbz np': 148,
#          'np bez': 536,
#          'bez vbn': 1758,
#          'vb rp': 1336,
#          'rp pp': 231,
#          'pp cd': 78,
#          'nr cc': 152,
#          'in nr': 261,
#          'nr wrb': 12,
#          'wrb dti': 15,
#          'dti in': 383,
#          'vbd md': 43,
#          'nn bez': 4197,
#          'vb wdt': 269,
#          'wdt nns': 117,
#          'cs ppss': 2520,
#          'np rb': 783,
#          'rb md': 363,
#          'nns cd': 500,
#          'vbn rbr': 58,
#          'rbr in': 177,
#          'cs pp': 665,
#          'pp od': 226,
#          'nns rb': 2025,
#          'rb pps': 1072,
#          'pps bedz': 2786,
#          'bez ql': 600,
#          'ql rb': 2029,
#          'rb beg': 39,
#          'beg jj': 76,
#          'od nns': 97,
#          'np ql': 93,
#          'vbd ex': 39,
#          'ex rb': 35,
#          'rb bez': 256,
#          'rb to': 626,
#          'rb vbz': 681,
#          'vbz to': 460,
#          'wdt jj': 99,
#          'ber vbn': 1085,
#          'vbn rp': 909,
#          'in rb': 1027,
#          'rb np': 615,
#          'nn wrb': 1024,
#          'wrb cs': 21,
#          'nr in': 390,
#          'vbg ppl': 71,
#          'ppl at': 66,
#          'nn ex': 272,
#          'bedz nn': 184,
#          'nn beg': 81,
#          'beg vbn': 353,
#          'in cs': 170,
#          'cc cs': 863,
#          'to rb': 30,
#          'rb be': 379,
#          '<START> cs': 2005,
#          'cs jj': 969,
#          'nns bed': 1255,
#          'bed rb': 392,
#          'rp np': 84,
#          'vbd rp': 1458,
#          'rp cs': 187,
#          'nns ap': 130,
#          'ap np': 104,
#          'jj np': 1889,
#          'nn pn': 135,
#          'pn pps': 58,
#          'pps hvz': 435,
#          'hvz rb': 245,
#          'vb vbn': 182,
#          'wps bez': 217,
#          'ex ber': 337,
#          'ber dti': 28,
#          '<START> cc': 2244,
#          'cs pn': 244,
#          'vbd ppo': 1948,
#          'wdt np': 183,
#          'nr md': 26,
#          'be rb': 301,
#          'np doz': 42,
#          'doz vb': 290,
#          'hvz at': 230,
#          'ppo in': 1854,
#          'nn ppss': 1705,
#          'ppss rb': 732,
#          'bez np': 82,
#          'np at': 1053,
#          'vbd np': 818,
#          'vbd cd': 328,
#          'np vbn': 217,
#          'dt bedz': 306,
#          'jjt jjt': 5,
#          '<START> beg': 15,
#          'beg in': 40,
#          'cs beg': 58,
#          'ppss dod': 251,
#          'cc ppss': 1142,
#          'dod hv': 51,
#          'bedz ql': 446,
#          'jj wrb': 122,
#          'wrb <END>': 31,
#          'vbd ppl': 197,
#          'ppl in': 244,
#          'np cd': 1084,
#          'nn abx': 64,
#          'pps rb': 784,
#          'rb bedz': 175,
#          '<START> ap': 443,
#          'ap jj': 802,
#          'be nns': 51,
#          'cc vbd': 2182,
#          'jj pp': 72,
#          '<START> pn': 276,
#          'pn vbd': 130,
#          'vbd ql': 259,
#          'jj at': 487,
#          '<START> ex': 779,
#          'jj nr': 99,
#          'pps hvd': 1328,
#          'hvd vbn': 2246,
#          'rp rb': 400,
#          'nns pps': 639,
#          'wdt nn': 285,
#          'vbd nns': 371,
#          'cs nns': 630,
#          'vbd ap': 201,
#          'ppss md': 2399,
#          'vb vb': 295,
#          'ap cd': 295,
#          'md rb': 1119,
#          'rb vb': 1852,
#          'rp nn': 99,
#          'cc ap': 562,
#          'ap <END>': 232,
#          'pps bez': 1819,
#          'bez rb': 1294,
#          'wrb pps': 883,
#          'vb pp': 1670,
#          'nns ppss': 593,
#          'ppss do': 475,
#          'do pn': 54,
#          'vb pps': 274,
#          'nn rp': 333,
#          'jj cs': 1773,
#          'rb ap': 138,
#          'ap nr': 26,
#          'np vbg': 371,
#          'jj in': 3980,
#          'ap jjt': 5,
#          'jjt nns': 176,
#          'vbg jjr': 28,
#          'jjr nns': 325,
#          'jj rb': 553,
#          '<START> vbg': 592,
#          'wdt md': 377,
#          'be cd': 46,
#          'ber rb': 606,
#          'vb nr': 94,
#          'nr nns': 58,
#          'np wrb': 164,
#          'ppss vbg': 230,
#          'vbg ap': 83,
#          'bed rbr': 5,
#          'rbr vbn': 74,
#          'ppo md': 91,
#          'ppo rb': 836,
#          'ppss jj': 143,
#          'vbd vbn': 174,
#          'wdt vbd': 404,
#          'vbz jj': 322,
#          'rbr <END>': 140,
#          'cd vbd': 178,
#          'dt vbd': 125,
#          'od vbd': 16,
#          'at rb': 351,
#          'rbr rp': 30,
#          'rp cc': 445,
#          'bed vbn': 1023,
#          'vb ap': 264,
#          'nns wps': 1098,
#          'wps vb': 429,
#          'cs dt': 530,
#          'rb nns': 290,
#          'bedz cd': 177,
#          'jj vbg': 592,
#          '<START> jj': 1265,
#          'np ap': 93,
#          'cc jjs': 9,
#          'nns nps': 7,
#          'vb <END>': 1251,
#          'wrb np': 278,
#          'np vbz': 665,
#          'cs jjr': 18,
#          'hvd rb': 434,
#          'cd to': 67,
#          '<START> abn': 201,
#          'abn np': 40,
#          'wps bedz': 186,
#          'bedz jj': 1143,
#          'nns nr': 84,
#          'rp nns': 97,
#          'cd vbg': 127,
#          'bez beg': 61,
#          'vbd dt': 237,
#          'dt cs': 38,
#          'vb np': 674,
#          'vb be': 12,
#          'vbn vbg': 173,
#          'abn pp': 126,
#          'cs ql': 82,
#          'vb rbt': 11,
#          'rbt in': 21,
#          'rb nn': 466,
#          'rb vbg': 1113,
#          'wps vbz': 425,
#          'hv in': 62,
#          'ppss ber': 712,
#          'vbg <END>': 631,
#          'be in': 262,
#          'rb wps': 29,
#          'nns bez': 471,
#          'np ber': 90,
#          'np cs': 552,
#          'cc bedz': 180,
#          'bedz in': 532,
#          'nn hv': 230,
#          'hv ben': 658,
#          'at ql': 1378,
#          '<START> md': 127,
#          'wdt hv': 41,
#          'hv vbn': 1281,
#          'vbn dts': 28,
#          'vbd wrb': 151,
#          'bez jj': 1416,
#          'dts pps': 6,
#          'ber cd': 74,
#          'jjs vbg': 6,
#          '<START> vbz': 48,
#          'nn ber': 618,
#          'ber nn': 47,
#          'abn nns': 438,
#          'nns ql': 315,
#          'vbg pp': 659,
#          'np jjs': 14,
#          'be ql': 253,
#          '<START> dti': 226,
#          'ppss vbd': 2835,
#          'ppss bed': 615,
#          'bed vbg': 321,
#          'vbg vbn': 92,
#          'vbg ppls': 28,
#          'ppls cc': 24,
#          'vbg dt': 161,
#          'dt rb': 141,
#          'rb pp': 259,
#          '<START> wdt': 400,
#          'wdt dt': 46,
#          'dt vbz': 197,
#          'jj bez': 102,
#          'bez cs': 261,
#          'ex bez': 562,
#          'nr vbd': 43,
#          'vb abn': 182,
#          'in wpo': 94,
#          'wpo pps': 71,
#          'rb hvd': 130,
#          'hvd abl': 3,
#          'abl at': 342,
#          'vbn vbn': 168,
#          'pps vbn': 115,
#          'ap ap': 133,
#          'nn bed': 372,
#          'jjt np': 12,
#          'cc ql': 450,
#          'in ql': 407,
#          'ql jjr': 215,
#          'ben jj': 205,
#          'in jjr': 226,
#          'rb cd': 733,
#          'cc dod': 60,
#          '<START> vbd': 26,
#          'np hvd': 759,
#          'vbn dt': 170,
#          'vbg cd': 123,
#          'dt <END>': 225,
#          'od od': 4,
#          'od cc': 78,
#          'cc od': 51,
#          'rb bed': 57,
#          'bed in': 182,
#          'wps hvd': 270,
#          'vbn pps': 166,
#          'wrb jj': 156,
#          'cc dti': 122,
#          'dti ap': 130,
#          'cd nps': 46,
#          'nps in': 155,
#          'cd wps': 76,
#          'wps ber': 189,
#          'ql ap': 547,
#          'ap cs': 346,
#          'dt in': 440,
#          'nn dt': 491,
#          'dts in': 165,
#          'cd cs': 153,
#          'rp md': 9,
#          '<START> abx': 84,
#          'vb rbr': 57,
#          'dts md': 27,
#          'ber in': 249,
#          'od cd': 83,
#          'dts wps': 217,
#          'vb pn': 233,
#          'pn cc': 56,
#          'jj vbn': 281,
#          'jj pps': 299,
#          'wps hv': 139,
#          'cc wps': 84,
#          'cc dts': 100,
#          'nn doz': 154,
#          'nn ql': 740,
#          'ap vbn': 92,
#          'dt jj': 792,
#          'dt nns': 21,
#          'cc md': 314,
#          'jj cd': 237,
#          'dt cd': 98,
#          'pps rbr': 14,
#          'rbr at': 62,
#          'jj vb': 83,
#          'cs vbn': 344,
#          'wps ap': 6,
#          'vbd vbg': 439,
#          'vbn ap': 149,
#          'vbg rb': 787,
#          'nns abn': 92,
#          'abn jj': 172,
#          'ap at': 113,
#          'nns hvz': 130,
#          'at jjr': 634,
#          'jjr jjr': 8,
#          'jjr cc': 133,
#          'cc jjr': 103,
#          'jjr jj': 90,
#          'dt hvz': 31,
#          'wps in': 74,
#          'pp ap': 132,
#          'nns hv': 570,
#          'vbg pn': 67,
#          'pn dt': 10,
#          'vbg hvz': 10,
#          'ben rb': 168,
#          'wrb nns': 117,
#          'hv rb': 258,
#          'nn hvn': 1,
#          'hvn jj': 12,
#          'ppo cc': 673,
#          'wps rb': 169,
#          'rp hvz': 1,
#          'np wdt': 126,
#          'md nns': 8,
#          'pp np': 125,
#          'jj ex': 27,
#          'ex hvz': 32,
#          'jj ql': 133,
#          'jj fw': 41,
#          'fw fw': 603,
#          'fw nn': 43,
#          'rb hvz': 90,
#          'ben ql': 90,
#          'ql in': 166,
#          'dt jjs': 2,
#          'bez nr': 10,
#          'nr jjr': 3,
#          'jjr in': 78,
#          'vbn dti': 68,
#          'in <END>': 172,
#          'at nr': 443,
#          'nr dt': 10,
#          'rb rb': 1365,
#          'vbn pp': 362,
#          'rb ben': 218,
#          'cs to': 153,
#          'nn ppl': 155,
#          'vbd dti': 85,
#          'in cc': 313,
#          'cc wrb': 293,
#          'cc hvz': 65,
#          'nn jjt': 28,
#          'pps vb': 228,
#          'cd rb': 215,
#          'ap jjr': 15,
#          'wrb vbn': 100,
#          'vbn md': 65,
#          'rb ql': 405,
#          'bez ap': 95,
#          'be dti': 33,
#          'dti ql': 21,
#          'rp at': 681,
#          'in beg': 169,
#          'vbg np': 280,
#          'nns vbz': 240,
#          'dti jj': 460,
#          'vb abl': 34,
#          'bez to': 276,
#          'at fw': 178,
#          'in vb': 66,
#          'bez dt': 122,
#          'beg at': 74,
#          'ap to': 133,
#          'vbz wrb': 58,
#          'jj hv': 7,
#          'hv np': 13,
#          'nn od': 33,
#          'od jj': 112,
#          'nns ben': 11,
#          'vbz bez': 33,
#          'bez nn': 228,
#          'pps doz': 155,
#          'ap nps': 40,
#          'np vb': 288,
#          'cs nps': 35,
#          'nps vb': 67,
#          'vb ppls': 114,
#          'ppls in': 87,
#          'nps cs': 38,
#          'ppss hvd': 596,
#          'vbd bedz': 65,
#          'bedz cs': 136,
#          'bedz jjr': 42,
#          'nps dti': 2,
#          'rb hv': 185,
#          'vbz <END>': 201,
#          'dti jjr': 20,
#          'rb dti': 78,
#          'vbn abx': 24,
#          'abx in': 97,
#          'vbn ql': 258,
#          'vb ql': 405,
#          'ql rbr': 191,
#          'rbr cs': 157,
#          'md in': 125,
#          'rb ex': 172,
#          'cc to': 297,
#          'ppo cs': 620,
#          'dti cd': 65,
#          'hvd ql': 21,
#          'nns hvd': 309,
#          'rb dod': 102,
#          'ap vbg': 72,
#          'bedz dti': 20,
#          'hvd dti': 22,
#          'np wpo': 15,
#          'hvd to': 260,
#          'at abn': 43,
#          'abn rb': 43,
#          'hv ap': 51,
#          'cd dt': 80,
#          'rb abn': 120,
#          'abn in': 424,
#          'nr pps': 47,
#          'cc pn': 127,
#          'pn rb': 247,
#          'jjt jj': 94,
#          'rp abn': 28,
#          'abn dt': 92,
#          'ber at': 295,
#          'np pps': 314,
#          'in hvg': 81,
#          'hvg at': 67,
#          'cd md': 86,
#          'wdt to': 67,
#          'do cc': 26,
#          'wrb to': 109,
#          'be dt': 13,
#          'vbg wdt': 61,
#          'vbd hvz': 5,
#          'hvz to': 57,
#          'md do': 216,
#          'do pps': 8,
#          'be to': 28,
#          'in od': 87,
#          'vbz rp': 196,
#          'vbg to': 627,
#          'pp nr': 55,
#          'pp vbz': 2,
#          'vbz pp': 238,
#          'vbg nr': 42,
#          'bez pp': 133,
#          'md ex': 3,
#          'ex be': 15,
#          'be nn': 74,
#          'vbg pps': 88,
#          'ben ap': 13,
#          'abx at': 74,
#          'cc dt': 401,
#          'do nn': 14,
#          'rb ber': 89,
#          'cs nr': 18,
#          'cc ber': 94,
#          'rb nr': 80,
#          'cs rb': 456,
#          'ap abn': 12,
#          'abn vb': 51,
#          'ppss bedz': 348,
#          'dt pps': 62,
#          'bedz wrb': 34,
#          'wpo ppss': 46,
#          'abx jj': 78,
#          'vbd abx': 18,
#          'cc dtx': 6,
#          'dtx vbd': 4,
#          'ppo wrb': 116,
#          'vb wrb': 293,
#          'vbn bez': 66,
#          'cs wdt': 56,
#          'wdt bez': 379,
#          'vbz nr': 13,
#          'vbz nns': 148,
#          'be ap': 40,
#          'hvz in': 29,
#          'vbg abx': 9,
#          'nr cs': 65,
#          'nns wrb': 347,
#          'dt ppss': 60,
#          'vb ppss': 407,
#          'ppo pps': 238,
#          'ppo wdt': 65,
#          'wdt bed': 48,
#          'nr jj': 39,
#          'pn hvz': 35,
#          'jj abn': 28,
#          'ppo np': 204,
#          'wdt ppss': 559,
#          '<START> nr': 66,
#          'vbn ppss': 119,
#          'bez pn': 73,
#          'pn vbn': 37,
#          'wrb md': 115,
#          'md at': 111,
#          'ppss bem': 211,
#          'bem in': 7,
#          'cc vbz': 348,
#          'hv ppo': 49,
#          'ppo abx': 15,
#          'np rbr': 20,
#          'rbr np': 26,
#          'cs abn': 158,
#          'abn nps': 10,
#          'abn nn': 224,
#          'ppo jj': 334,
#          'wrb pn': 45,
#          'pn vbg': 34,
#          '<START> abl': 38,
#          'hv pp': 51,
#          'nr np': 48,
#          'np dti': 16,
#          'cc bez': 156,
#          'vbd vbz': 8,
#          'vbn ppo': 558,
#          'bez rbt': 7,
#          'rbt vbn': 29,
#          'vbz dt': 76,
#          'cd pps': 122,
#          'wrb ppss': 712,
#          'ppss pp': 4,
#          'ppss at': 70,
#          'jj ppss': 191,
#          'ppss nps': 5,
#          'cc wdt': 193,
#          'vbz nps': 3,
#          'nps np': 16,
#          '<START> to': 216,
#          'dod in': 45,
#          'nps at': 51,
#          'vbz vbz': 22,
#          'vbz cc': 148,
#          'cd bez': 99,
#          'ppo vbg': 181,
#          'nns ex': 95,
#          'vbz pps': 61,
#          'nps <END>': 147,
#          'ppss be': 78,
#          'in wrb': 116,
#          'rb dt': 261,
#          'nns wp': 62,
#          'wp jj': 37,
#          'be vbg': 200,
#          'rp nr': 19,
#          'jj nps': 158,
#          'nps vbd': 113,
#          'ben vbg': 217,
#          'dti vbd': 10,
#          'dts vb': 17,
#          'vb ex': 35,
#          'rp abl': 3,
#          'hv pn': 38,
#          'pn jj': 155,
#          'ber abn': 40,
#          'bez rp': 26,
#          'rp <END>': 590,
#          'vbg bez': 62,
#          'wps bed': 98,
#          'ap uh': 1,
#          'uh <END>': 40,
#          'ber nns': 146,
#          'jjr bez': 4,
#          'nn dti': 126,
#          'hvg vbn': 86,
#          'nps cc': 165,
#          'wrb vbz': 4,
#          'wrb cd': 30,
#          'ber np': 30,
#          'dts bed': 34,
#          'nns dt': 181,
#          'wrb do': 46,
#          'do ppss': 162,
#          'vbz ppss': 48,
#          'do vb': 618,
#          'md jj': 17,
#          'md <END>': 73,
#          'vbz abn': 42,
#          'abn vbg': 32,
#          'vbg vb': 32,
#          'vbd pn': 127,
#          'pn ppss': 51,
#          'hvd np': 30,
#          '<START> vbn': 286,
#          'jj dt': 59,
#          'cd ber': 33,
#          'at pn': 148,
#          'pn bedz': 54,
#          'dt vbg': 67,
#          'hvd at': 431,
#          'wdt ber': 154,
#          'ber to': 57,
#          'nns dod': 70,
#          'dod jj': 7,
#          'ber beg': 43,
#          'pn md': 224,
#          'nns dti': 45,
#          'dti at': 4,
#          'cc abn': 144,
#          'rp to': 171,
#          'hvd dt': 16,
#          'ppo dod': 10,
#          'ber ap': 90,
#          'wdt doz': 25,
#          'doz cd': 1,
#          'cd vb': 71,
#          'vbn ppl': 47,
#          'rb wdt': 157,
#          'dti vb': 14,
#          'hvz hvn': 27,
#          'hvn ql': 7,
#          'ap wps': 20,
#          'cs md': 43,
#          'md np': 22,
#          'rb pn': 130,
#          'hvd in': 63,
#          'cd ql': 45,
#          'np hv': 62,
#          'ber cs': 26,
#          'wps dod': 43,
#          'jj qlp': 166,
#          'qlp at': 5,
#          'cd bedz': 93,
#          'rp dti': 32,
#          'be rp': 20,
#          'pn bez': 77,
#          'md ql': 52,
#          'md cc': 67,
#          'cc hv': 66,
#          'in dtx': 43,
#          'dtx nn': 39,
#          'ap vb': 34,
#          'rp pps': 71,
#          'ppls <END>': 47,
#          ...})

# %% [markdown]
# ## 4.2
# A transition probability is the probability of a tag given its previous tag.

# %%
## calculate the probability of transition
prob_transition = {}
lambda_val = 0.1
smoothed_prob_transition = {}
for i in bigram_counter_tag:
    previous_tag = i.split(" ")[0]
    prob_transition[i] = (bigram_counter_tag[i] + lambda_val)/(counter_tag[previous_tag] + (lambda_val * len(counter_tag)))
    smoothed_prob_transition[previous_tag] = (lambda_val)/((counter_tag[previous_tag] +lambda_val * len(counter_tag)))

# %%
prob_transition
# Out:
# {'<START> at': 0.1567492251141233,
#  'at np': 0.030845006925617438,
#  'np nn': 0.13014180054206892,
#  'nn jj': 0.013538283995062374,
#  'jj nn': 0.4589713243453828,
#  'nn vbd': 0.026386188083239066,
#  'vbd nr': 0.004405612384016703,
#  'nr at': 0.04505005561735261,
#  'at nn': 0.5350687155886571,
#  'nn in': 0.27753212275926437,
#  'in np': 0.07020010754213442,
#  'np jj': 0.022446871389091527,
#  'nn nn': 0.1041453984469751,
#  'vbd at': 0.15433666513450556,
#  'nn cs': 0.027591803732969933,
#  'cs dti': 0.0102259660138354,
#  'dti nns': 0.13034335355763926,
#  'nns vbd': 0.029084578952320875,
#  'vbd nn': 0.023687470298148165,
#  'nn <END>': 0.12339326222800172,
#  '<END> <START>': 0.9997591988112241,
#  'nn rbr': 0.0007563588727913541,
#  'rbr vbd': 0.042681887885500085,
#  'vbd in': 0.17256678534422987,
#  'in nn': 0.15463387841141132,
#  'nn nns': 0.043384768935663315,
#  'nns cs': 0.026139702166662598,
#  'cs at': 0.25932703013488606,
#  'nn wdt': 0.008883767854807887,
#  'wdt hvd': 0.02482562738189401,
#  'hvd jj': 0.01192822534285949,
#  'in at': 0.3590793931456734,
#  'nn vbz': 0.014881855664414185,
#  'vbz at': 0.19575250207947623,
#  'nn cc': 0.08294215804001685,
#  'cc nns': 0.055784837898862516,
#  'nns in': 0.2726903627600291,
#  'np in': 0.06472611675248537,
#  'in wdt': 0.011785925175745619,
#  'wdt at': 0.08684475444020996,
#  'nn bedz': 0.017892895744836546,
#  'bedz vbn': 0.22945436690603327,
#  'vbn <END>': 0.06263682062646955,
#  'nn hvd': 0.004961018427325369,
#  'hvd ben': 0.15810544469081053,
#  'ben vbn': 0.4581218274111674,
#  'vbn in': 0.3584396367665739,
#  'nn np': 0.02023814807839261,
#  'np np': 0.19627633799966984,
#  'np to': 0.007590562250065229,
#  'to vb': 0.8277717031817384,
#  'vb nns': 0.026952016407908227,
#  'in jj': 0.07337523957814454,
#  'jj nns': 0.18734062522135386,
#  'at jj': 0.2157559326736147,
#  'wdt bedz': 0.04118429567843532,
#  'np <END>': 0.074603698635243,
#  '<START> rb': 0.07586472324328329,
#  'rb at': 0.07547543581616481,
#  'nns bedz': 0.004776276490822092,
#  'vbn at': 0.051251993189373256,
#  'nn at': 0.02466473688188206,
#  'in nns': 0.04717421495891297,
#  'nns cc': 0.10673174437772488,
#  'cc at': 0.10743993098453541,
#  'in dt': 0.02693584089042248,
#  'dt nn': 0.49946995295832514,
#  'vbd pps': 0.017143324581836882,
#  'pps dod': 0.021550153278881816,
#  'dod vb': 0.5336199605300254,
#  'vb cs': 0.04376535260308602,
#  'cs ap': 0.010180334750944568,
#  'ap in': 0.1304022431167517,
#  'cc nn': 0.12440090742555276,
#  'nns ber': 0.029136854871592913,
#  'ber jj': 0.15710481177214047,
#  'jj cc': 0.05185730644818549,
#  'cc jj': 0.09487230008946448,
#  'cc rb': 0.06805957909087035,
#  'rb jj': 0.04570489498002276,
#  'jj <END>': 0.03686427171628928,
#  '<START> pps': 0.11470163292019807,
#  'pps vbd': 0.3253210281475765,
#  'vbd cs': 0.04526756986265085,
#  'cs np': 0.059279573621479544,
#  'np nns': 0.027532095485066476,
#  'nns vb': 0.03046117815981794,
#  'vb to': 0.03616357825952159,
#  'to hv': 0.022550250408347846,
#  'hv dts': 0.002056463897633797,
#  'dts nns': 0.48896119943982197,
#  'nns vbn': 0.02443202213710928,
#  'vbn cc': 0.04317788708413286,
#  'cc vbn': 0.027827184424658112,
#  'in vbg': 0.031653179915351805,
#  'vbg cc': 0.034712286506304216,
#  'cc vbg': 0.02891886422698419,
#  'vbg ppo': 0.036333050165429676,
#  'ppo <END>': 0.18164824743772112,
#  'in ap': 0.01258589350689622,
#  'ap nns': 0.2505692119576675,
#  'in ppo': 0.03238717147692297,
#  'ppo at': 0.05189298610351242,
#  'np cc': 0.07404459022678501,
#  'cc np': 0.05791494483023047,
#  'nn vbg': 0.012764530667623161,
#  'vbg nns': 0.0911036841634624,
#  'nns wdt': 0.012199457027451828,
#  'wdt pps': 0.09691162723808154,
#  'vbd ber': 0.0002765680630107745,
#  'ber ql': 0.06208811049923265,
#  'ql vbn': 0.06056998890532545,
#  'cc vb': 0.04209890086482341,
#  'vb rb': 0.0475215234552002,
#  'rb vbn': 0.08699861610231914,
#  'vbn nns': 0.061049025702008056,
#  'wdt vb': 0.0330948443230028,
#  'vb in': 0.14607629200352962,
#  'at jjt': 0.006926637413837772,
#  'jjt nn': 0.42707106399685907,
#  'in abx': 0.0018811626426335287,
#  'abx nns': 0.2505414185165133,
#  'nns <END>': 0.1336712681092497,
#  '<START> nn': 0.040732447239842096,
#  'nn vbn': 0.013586268697539225,
#  'vbn wrb': 0.004057322775060134,
#  'wrb at': 0.18375784912001414,
#  'pps vbz': 0.07305400132913156,
#  'vbz dts': 0.0030990903968445625,
#  'dts cd': 0.03134525084438586,
#  'cd nns': 0.2438064288045252,
#  'nns md': 0.024797953572013563,
#  'md be': 0.27796710736509,
#  'be vbn': 0.4840914858520492,
#  'vbn to': 0.05236682792356963,
#  'vb jjr': 0.001970499153371014,
#  'jjr nn': 0.3559672859450727,
#  'vb at': 0.18336970260666333,
#  'vbg nn': 0.1676707949566306,
#  'vbd bez': 0.0008219135393700482,
#  'bez vbg': 0.03822275486748267,
#  'vbg in': 0.1657147008852723,
#  'in vbn': 0.005443908199922807,
#  'vbn jj': 0.030712007783573417,
#  'nns nns': 0.015945897908614722,
#  'nn vb': 0.006718458155540014,
#  'nns to': 0.017897532228104227,
#  'vb dt': 0.016637452004483556,
#  'bedz rb': 0.12133022361341271,
#  'at ap': 0.03046761687361921,
#  'ap nn': 0.28946536239827975,
#  'vb vbg': 0.008976055901361761,
#  'cs cs': 0.03317849124792378,
#  'nn md': 0.01999222647819875,
#  '<START> dt': 0.034146431820333494,
#  'dt bez': 0.06869630513041367,
#  'bez cd': 0.015530756989331814,
#  'cd in': 0.1407388774067225,
#  'vbd cc': 0.02325898456672302,
#  'nn hvz': 0.005554829120476393,
#  'hvz vbn': 0.39227708299496505,
#  'jj to': 0.01930353221731636,
#  'vb dts': 0.00438518041544442,
#  'in abn': 0.008718005390302075,
#  'abn at': 0.17996495720735897,
#  'at nns': 0.07738638009502069,
#  'wdt vbz': 0.06868843028690588,
#  'vbz pn': 0.0061847648179452095,
#  'pn in': 0.18741009917480506,
#  'vbd ppss': 0.010793945107082481,
#  'ppss vb': 0.2322376179245283,
#  'in dts': 0.008635534428327785,
#  'md vb': 0.4543732599005006,
#  'in pp': 0.06296740417698929,
#  'pp ql': 0.004878831457469188,
#  'ql jj': 0.5052815273668639,
#  'rb ppss': 0.023802482087453405,
#  'cs in': 0.03988628689287605,
#  'vb dti': 0.008648136223796237,
#  'dti nn': 0.4037162162162162,
#  'dts jj': 0.10383886646346485,
#  'nns at': 0.024675976427045467,
#  'vbd <END>': 0.053486705256351325,
#  'nn to': 0.017167127119874184,
#  'to do': 0.026060017008868914,
#  'do dt': 0.03129110039456379,
#  'dt md': 0.023642306588043022,
#  'nn rb': 0.023890983554442843,
#  'rb vbd': 0.05011327872145711,
#  'wdt hvz': 0.014938520169698712,
#  'hvz ben': 0.24285366249796977,
#  'ben in': 0.06676764368757163,
#  'pp nns': 0.1931387347127967,
#  '<START> nns': 0.02146835213777944,
#  'pp vbg': 0.014268056430430597,
#  'in cd': 0.034316991987121334,
#  'cd jj': 0.053648156205808775,
#  'jj jj': 0.0653598918612613,
#  'nns nn': 0.021992479237747393,
#  '<START> dts': 0.008234577404204347,
#  'cc in': 0.05927288799897754,
#  'cc pp': 0.0240196182848379,
#  'pp vbn': 0.010643102485173344,
#  '<START> in': 0.09193871712652148,
#  'cs wrb': 0.0036550641575556243,
#  'vbz nn': 0.04978668598567174,
#  'nn cd': 0.008403920830039383,
#  'cd at': 0.02808522789078647,
#  'nn be': 0.0009782881217467872,
#  'nn wps': 0.009285639738051509,
#  'wps md': 0.10273039265166044,
#  'vb jj': 0.04152953661968471,
#  'nn dod': 0.0008583263655546612,
#  'vb cc': 0.024775822184064294,
#  'cc pps': 0.03877060878456098,
#  'cs ex': 0.01355704820486612,
#  'ex md': 0.08816984155243011,
#  'be jj': 0.1494258342849892,
#  'at vbg': 0.016504184949684725,
#  'vbg at': 0.14112380398819638,
#  'nns jj': 0.01709596813259961,
#  '<START> vb': 0.01953371010829879,
#  'vb nn': 0.04847547160811809,
#  'cs cd': 0.011366747586106193,
#  'cd cd': 0.054871913412378986,
#  'nns be': 0.0010124103032351825,
#  '<START> cd': 0.019801266984716327,
#  'cd np': 0.02828918742521484,
#  'nns np': 0.009829615353785997,
#  'np vbd': 0.10540790952028498,
#  'pp nn': 0.5281795600137867,
#  'nn nr': 0.0012781925122271021,
#  'nr <END>': 0.15679037314187483,
#  '<START> pp': 0.02023347424662158,
#  'vbd jj': 0.02734907563941757,
#  'vbn cd': 0.006320775114186103,
#  'cd <END>': 0.1022585119112368,
#  '<START> ppss': 0.07849912941108672,
#  'ppss hv': 0.056757879502572904,
#  'hv at': 0.13280694627805423,
#  'vbn rb': 0.049630415394178534,
#  'rb <END>': 0.0767030869846655,
#  'cs nn': 0.05211546534761896,
#  'vbd pp': 0.0483448764792496,
#  'cd cc': 0.05983492875013598,
#  'rb cs': 0.059097453181848614,
#  'np nr': 0.0012273760776148968,
#  'nr bez': 0.022297502275255336,
#  'bez in': 0.05030550698442013,
#  '<START> np': 0.07827273513104112,
#  'np bedz': 0.02827757336301045,
#  'np hvz': 0.008495785387568624,
#  'ben nn': 0.009865727853283117,
#  'pp jj': 0.18285812762214906,
#  'vbz rb': 0.055823875070433876,
#  'rb in': 0.16149472109997545,
#  'vbz cd': 0.011148675843194074,
#  'pps md': 0.11608999506935065,
#  'np wps': 0.010545849551914547,
#  'wps vbd': 0.24202584031492883,
#  'at cd': 0.010374146537497271,
#  'cd nn': 0.12415016860654846,
#  'cs pps': 0.13854107726285433,
#  'np nps': 0.0018929813257791573,
#  'nps ber': 0.03366174055829228,
#  'ber vbg': 0.06998736119888056,
#  'vbg jj': 0.041363006348922475,
#  'at jjs': 0.0021123643180765753,
#  'jjs nn': 0.5723447922011288,
#  'vbn nr': 0.0025033107213318557,
#  'nr nn': 0.14313884113661646,
#  'bedz vbg': 0.08624358108799281,
#  'vbg rp': 0.031191317177859255,
#  'rp in': 0.3430584516042241,
#  'to be': 0.11441164162583188,
#  'wdt rb': 0.031656719637592576,
#  'vbn np': 0.013989486770627823,
#  'np md': 0.01826687043061997,
#  'be at': 0.09740197944423297,
#  'at vbn': 0.01944170751658986,
#  'vbn nn': 0.08408894354206643,
#  'vbn cs': 0.044596767654928246,
#  'cs vbg': 0.020310475112709222,
#  'vb ppo': 0.09065786649495598,
#  'ppo to': 0.04961337856074699,
#  'nns rp': 0.002476136042852313,
#  'vbg ex': 0.000508584458553161,
#  'ex bedz': 0.24928787609043973,
#  'bedz at': 0.16705538165674422,
#  'in in': 0.011365323269676746,
#  'in nps': 0.0008832640027446335,
#  'nps wps': 0.03963278101209136,
#  '<START> wrb': 0.017804881060677784,
#  'vbd to': 0.04764371800964482,
#  'vb cd': 0.010645465168968067,
#  'cd ap': 0.009660883280757098,
#  'nn pps': 0.013496297380395131,
#  'vbd rb': 0.07366448788164445,
#  'rb cc': 0.038338987969018544,
#  'cc ex': 0.005887083031568184,
#  'ex bed': 0.09885170019583406,
#  'bed at': 0.058659217877094966,
#  'at nps': 0.005998461880544829,
#  'nps md': 0.0329153605015674,
#  'md hv': 0.08048958602747645,
#  'hv to': 0.06654310957652076,
#  'vb bez': 0.0019406882735923299,
#  'bez at': 0.206595414448221,
#  'vbz cs': 0.060385306823365265,
#  'at od': 0.013729858080940986,
#  'od nn': 0.6107196542653137,
#  'nns vbg': 0.01946580980626544,
#  'vbg cs': 0.02057252079048556,
#  'nps be': 0.0008210180623973728,
#  'cc cd': 0.019972415115238784,
#  'vbz in': 0.18394644342483027,
#  'nr to': 0.019263828496309032,
#  'in dti': 0.009031395045804372,
#  'wps hvz': 0.03358736247098011,
#  'ben at': 0.09542328475519894,
#  'nn ap': 0.0018540089419493068,
#  'vbz np': 0.01986906007673938,
#  'np bez': 0.014273238941634406,
#  'bez vbn': 0.17270476826656714,
#  'vb rp': 0.039830316472299725,
#  'rp pp': 0.03886123629515033,
#  'pp cd': 0.0046411295594195314,
#  'nr cc': 0.0769036302962888,
#  'in nr': 0.0021533168171486822,
#  'nr wrb': 0.006117908787541713,
#  'wrb dti': 0.0033386397806668433,
#  'dti in': 0.13206701599558743,
#  'vbd md': 0.0016788850022203352,
#  'nn bez': 0.025174574345698596,
#  'vb wdt': 0.008022107748443872,
#  'wdt nns': 0.021050550082692167,
#  'cs ppss': 0.11499534561118513,
#  'np rb': 0.0208494187934973,
#  'rb md': 0.010130912256422847,
#  'nns cd': 0.008714395742649135,
#  'vbn rbr': 0.001962784789600281,
#  'rbr in': 0.15087749190662805,
#  'cs pp': 0.03034935294869221,
#  'pp od': 0.013436099787256801,
#  'nns rb': 0.03528798803926967,
#  'rb pps': 0.029912836767036446,
#  'pps bedz': 0.14931828413402792,
#  'bez ql': 0.058950077604668076,
#  'ql rb': 0.23450212647928995,
#  'rb beg': 0.0010909354701903976,
#  'beg jj': 0.11096529600466608,
#  'od nns': 0.04561255167230364,
#  'np ql': 0.0024787139441637064,
#  'vbd ex': 0.0015230720089748286,
#  'ex rb': 0.01562221826597828,
#  'rb bez': 0.007145487823932502,
#  'rb to': 0.017468918104506594,
#  'rb vbz': 0.019003482065132474,
#  'vbz to': 0.06172690439775685,
#  'wdt jj': 0.017814769540519162,
#  'ber vbn': 0.24489934097679875,
#  'vbn rp': 0.030712007783573417,
#  'in rb': 0.008470592504379208,
#  'rb np': 0.01716200531238142,
#  'nn wrb': 0.006142641725817809,
#  'wrb cs': 0.004665251614044397,
#  'nr in': 0.19723935686115887,
#  'vbg ppl': 0.003973665384959313,
#  'ppl at': 0.054100507448027496,
#  'nn ex': 0.0016320796929938737,
#  'bedz nn': 0.018832218335072322,
#  'nn beg': 0.00048644492135907074,
#  'beg vbn': 0.5148731408573929,
#  'in cs': 0.0014028310631826533,
#  'cc cs': 0.02298119115579602,
#  'to rb': 0.002031614897609309,
#  'rb be': 0.010577330863150375,
#  '<START> cs': 0.04126756099267717,
#  'cs jj': 0.04422125686750507,
#  'nns bed': 0.021870502092779298,
#  'bed rb': 0.12035729633494997,
#  'rp np': 0.014142059595076343,
#  'vbd rp': 0.05679773136281834,
#  'rp cs': 0.03146229905159077,
#  'nns ap': 0.0022670323657641516,
#  'ap np': 0.010973141628367837,
#  'jj np': 0.027877305031520788,
#  'nn pn': 0.0008103416630778108,
#  'pn pps': 0.021992580816110226,
#  'pps hvz': 0.023318755761356575,
#  'hvz rb': 0.09952087055384115,
#  'vb vbn': 0.005428561207698361,
#  'wps bez': 0.054784495811042694,
#  'ex ber': 0.150035606195478,
#  'ber dti': 0.006341969847431615,
#  '<START> cc': 0.04618649125912266,
#  'cs pn': 0.011138591271652034,
#  'vbd ppo': 0.07588482303539291,
#  'wdt np': 0.03291507873732653,
#  'nr md': 0.013196480938416423,
#  'be rb': 0.047757264306560084,
#  'np doz': 0.001120879237908615,
#  'doz vb': 0.5003449465332874,
#  'hvz at': 0.0934302420009745,
#  'ppo in': 0.16906481380165592,
#  'nn ppss': 0.010227339524159699,
#  'ppss rb': 0.049052583619210985,
#  'bez np': 0.008064991453663137,
#  'np at': 0.028037955473671314,
#  'vbd np': 0.031867652443537266,
#  'vbd cd': 0.012780560770962691,
#  'np vbn': 0.00578011597505844,
#  'dt bedz': 0.033801541553479544,
#  'jjt jjt': 0.005005889281507656,
#  '<START> beg': 0.00031077760260806207,
#  'beg in': 0.05847185768445612,
#  'cs beg': 0.002651176373957326,
#  'ppss dod': 0.016824346054888507,
#  'cc ppss': 0.03040993907894176,
#  'dod hv': 0.036016351846630955,
#  'bedz ql': 0.045633093966734185,
#  'jj wrb': 0.0018018204141383135,
#  'wrb <END>': 0.00687627133634032,
#  'vbd ppl': 0.007677685242172345,
#  'ppl in': 0.199787199214274,
#  'np cd': 0.028863305981395,
#  'nn abx': 0.0003844774285957637,
#  'pps rb': 0.04202306686389264,
#  'rb bedz': 0.004885493627374388,
#  '<START> ap': 0.009119573226200816,
#  'ap jj': 0.0845490576379812,
#  'be nns': 0.008104935921837331,
#  'cc vbd': 0.05810132918672516,
#  'jj pp': 0.0010639742167024766,
#  '<START> pn': 0.005682496429144765,
#  'pn vbd': 0.04924672571731395,
#  'vbd ql': 0.0100927866374777,
#  'jj at': 0.007188097655419923,
#  '<START> ex': 0.016034889416684846,
#  'jj nr': 0.0014624111633178285,
#  'pps hvd': 0.0711782108174159,
#  'hvd vbn': 0.46113574772111354,
#  'rp rb': 0.0672798816170041,
#  'nns pps': 0.011136513335587007,
#  'wdt nn': 0.051251168476306896,
#  'vbd nns': 0.01445555044835189,
#  'cs nns': 0.0287522587475131,
#  'vbd ap': 0.007833498235417851,
#  'ppss md': 0.16074587264150944,
#  'vb vb': 0.008797190622689657,
#  'ap cd': 0.031106379390310752,
#  'md rb': 0.08512985135936953,
#  'rb vb': 0.05167574384500345,
#  'rp nn': 0.016664424564471647,
#  'cc ap': 0.01496666382652409,
#  'ap <END>': 0.024465573217523295,
#  'pps bez': 0.09749287199605548,
#  'bez rb': 0.1271243049961689,
#  'wrb pps': 0.19525515167595295,
#  'vb pp': 0.049787150318380186,
#  'nns ppss': 0.010334949240082388,
#  'ppss do': 0.03183292238421956,
#  'do pn': 0.02964708461201228,
#  'vb pps': 0.008171162147337293,
#  'nn rp': 0.001997963049379858,
#  'jj cs': 0.026165501853469646,
#  'rb ap': 0.003853150599316979,
#  'ap nr': 0.0027511911287262307,
#  'np vbg': 0.009880244303750287,
#  'jj in': 0.05873403300828749,
#  'ap jjt': 0.0005375890711304127,
#  'jjt nns': 0.17285041224970554,
#  'vbg jjr': 0.0015704640972905304,
#  'jjr nns': 0.164125605815832,
#  'jj rb': 0.008162054636035228,
#  '<START> vbg': 0.012186186655909507,
#  'wdt md': 0.06778960235852449,
#  'be cd': 0.007311889354142875,
#  'ber rb': 0.13679245283018868,
#  'vb nr': 0.0028052037871741666,
#  'nr nns': 0.029376074426130046,
#  'np wrb': 0.004369032848950207,
#  'ppss vbg': 0.015417292024013722,
#  'vbg ap': 0.00464432620942502,
#  'bed rbr': 0.0015654736325127385,
#  'rbr vbn': 0.06312830124382347,
#  'ppo md': 0.008306889885837254,
#  'ppo rb': 0.0762391946602473,
#  'ppss jj': 0.009588068181818182,
#  'vbd vbn': 0.006781760531010681,
#  'wdt vbd': 0.072643273171784,
#  'vbz jj': 0.04321285787115297,
#  'rbr <END>': 0.11935593797921282,
#  'cd vbd': 0.012108397693897531,
#  'dt vbd': 0.013814351023653349,
#  'od vbd': 0.007562946260804209,
#  'at rb': 0.003581125601529144,
#  'rbr rp': 0.02564321008689726,
#  'rp cc': 0.07484697652519003,
#  'bed vbn': 0.3140462889066241,
#  'vb ap': 0.007873053349550452,
#  'nns wps': 0.019134728984209183,
#  'wps vb': 0.10828202281215302,
#  'cs dt': 0.02418913245842992,
#  'rb nns': 0.008094127363228499,
#  'bedz cd': 0.01811616440598212,
#  'jj vbg': 0.00873757467003518,
#  '<START> jj': 0.02603740033506353,
#  'np ap': 0.0024787139441637064,
#  'cc jjs': 0.0002422996634431048,
#  'nns nps': 0.0001237196756104956,
#  'vb <END>': 0.03729639169111158,
#  'wrb np': 0.06148845847704962,
#  'np vbz': 0.017707762022161993,
#  'cs jjr': 0.0008259258583240551,
#  'hvd rb': 0.0891229366839123,
#  'cd to': 0.004561894920047862,
#  '<START> abn': 0.004138899065197436,
#  'abn np': 0.013511692162544645,
#  'wps bedz': 0.04696174422125769,
#  'bedz jj': 0.11693160662043003,
#  'nns nr': 0.0014654682702595324,
#  'rp nns': 0.01632810923521894,
#  'cd vbg': 0.00864108560861525,
#  'bez beg': 0.006002082555649424,
#  'vbd dt': 0.009235815174627413,
#  'dt cs': 0.0042072483932949056,
#  'vb np': 0.020095514058810902,
#  'vb be': 0.0003607116453220767,
#  'vbn vbg': 0.005847814923920975,
#  'abn pp': 0.04248938607722892,
#  'cs ql': 0.0037463266833372877,
#  'vb rbt': 0.0003309007655433927,
#  'rbt in': 0.1904332129963899,
#  'rb nn': 0.013004732037231312,
#  'rb vbg': 0.031056784446775735,
#  'wps vbz': 0.10727263551024528,
#  'hv in': 0.015766223215192443,
#  'ppss ber': 0.04771253216123499,
#  'vbg <END>': 0.035271170526692305,
#  'be in': 0.041571501078543335,
#  'rb wps': 0.0008119238409856922,
#  'nns bez': 0.008209061856352744,
#  'np ber': 0.0023988413143839955,
#  'np cs': 0.014699226300459533,
#  'cc bedz': 0.004795403229242107,
#  'bedz in': 0.05443032795269953,
#  'nn hv': 0.0013801600049904092,
#  'hv ben': 0.16708134457195084,
#  'at ql': 0.014056249477263779,
#  '<START> md': 0.002615882999436072,
#  'wdt hv': 0.007388365571295031,
#  'hv vbn': 0.3252513455874885,
#  'vbn dts': 0.0009492986676035783,
#  'vbd wrb': 0.0058858358198490175,
#  'bez jj': 0.13910882335605806,
#  'dts pps': 0.0025125628140703514,
#  'ber cd': 0.016723842195540305,
#  'jjs vbg': 0.015649050795279628,
#  '<START> vbz': 0.0009899604427448866,
#  'nn ber': 0.003707418075117653,
#  'ber nn': 0.010630134512954772,
#  'abn nns': 0.14761776400026955,
#  'nns ql': 0.005490714054206643,
#  'vbg pp': 0.036836045783778956,
#  'np jjs': 0.00037540135996464303,
#  'be ql': 0.04014401725669331,
#  '<START> dti': 0.0046534315198465456,
#  'ppss vbd': 0.18995899442538594,
#  'ppss bed': 0.04121328259005146,
#  'bed vbg': 0.0985634477254589,
#  'vbg vbn': 0.0051473218277743,
#  'vbg ppls': 0.0015704640972905304,
#  'ppls cc': 0.06831065759637188,
#  'vbg dt': 0.009003621568452115,
#  'dt rb': 0.01558117449590318,
#  'rb pp': 0.0072291913126939136,
#  '<START> wdt': 0.008234577404204347,
#  'wdt dt': 0.008287193499676422,
#  'dt vbz': 0.02176505664877758,
#  'jj bez': 0.0015066819351639788,
#  'bez cs': 0.02564883396530384,
#  'ex bez': 0.25017803097739005,
#  'nr vbd': 0.021791889978764283,
#  'vb abn': 0.005428561207698361,
#  'in wpo': 0.000776051752178058,
#  'wpo pps': 0.24200136147038798,
#  'rb hvd': 0.003629941295953215,
#  'hvd abl': 0.0006364457583969779,
#  'abl at': 0.940351841671248,
#  'vbn vbn': 0.005678900570254858,
#  'pps vbn': 0.006168671082813471,
#  'ap ap': 0.014030020660285872,
#  'nn bed': 0.0022318884739545037,
#  'jjt np': 0.0118767177071064,
#  'cc ql': 0.011984514122608954,
#  'in ql': 0.0033573928619732994,
#  'ql jjr': 0.024859005177514795,
#  'ben jj': 0.08396102832814802,
#  'in jjr': 0.0018646684502386709,
#  'rb cd': 0.02045434253699694,
#  'cc dod': 0.001600242832190176,
#  '<START> vbd': 0.0005371718826536702,
#  'np hvd': 0.020210437755259613,
#  'vbn dt': 0.005746466311721305,
#  'vbg cd': 0.006879862290977376,
#  'dt <END>': 0.02485699772521478,
#  'od od': 0.0019259676813228107,
#  'od cc': 0.03668733558812476,
#  'cc od': 0.001360605802411281,
#  'rb bed': 0.001593156402758867,
#  'bed in': 0.05589661734913131,
#  'wps hvd': 0.06815887756132027,
#  'vbn pps': 0.005611334828788411,
#  'wrb jj': 0.034514017865039354,
#  'cc dti': 0.00325107570400034,
#  'dti ap': 0.04484969663541092,
#  'cd nps': 0.0031341781790492768,
#  'nps in': 0.11576354679802955,
#  'cd wps': 0.00517377352333297,
#  'wps ber': 0.0477187846976885,
#  'ql ap': 0.06322808801775148,
#  'ap cs': 0.03648227010161488,
#  'dt in': 0.04859868813357186,
#  'nn dt': 0.002945660923297653,
#  'dts in': 0.06800395419721558,
#  'cd cs': 0.010408734906994453,
#  'rp md': 0.0015302347480998183,
#  '<START> abx': 0.001730887177439604,
#  'vb rbr': 0.0017022012353628579,
#  'dts md': 0.011162369223165006,
#  'ber in': 0.0562200956937799,
#  'od cd': 0.039036076662908675,
#  'dts wps': 0.0894225224483071,
#  'vb pn': 0.0069489160764112465,
#  'pn cc': 0.021235521235521235,
#  'jj vbn': 0.004148171321984275,
#  'jj pps': 0.004413795953061177,
#  'wps hv': 0.03510144342384172,
#  'cc wps': 0.002239274911600562,
#  'cc dts': 0.002665296297874153,
#  'nn doz': 0.0009243053314603305,
#  'nn ql': 0.004439184787889621,
#  'ap vbn': 0.009708226166884514,
#  'dt jj': 0.0874688045230681,
#  'dt nns': 0.0023299984540294623,
#  'cc md': 0.008363332339283432,
#  'jj cd': 0.003498866668240738,
#  'dt cd': 0.010832836414231764,
#  'pps rbr': 0.0007556756061483054,
#  'rbr at': 0.05290509456466178,
#  'jj vb': 0.0012263003801383607,
#  'cs vbn': 0.015701717560735212,
#  'wps ap': 0.0015393156354093064,
#  'vbd vbg': 0.017104371333525503,
#  'vbn ap': 0.0050370260263236126,
#  'vbg rb': 0.043989761244746496,
#  'nns abn': 0.0016048707216516401,
#  'abn jj': 0.0579890828222926,
#  'ap at': 0.01192182822448033,
#  'nns hvz': 0.0022670323657641516,
#  'at jjr': 0.006467649512758844,
#  'jjr jjr': 0.004089256865912763,
#  'jjr cc': 0.06719507269789984,
#  'cc jjr': 0.0027451753078004512,
#  'jjr jj': 0.045486672051696285,
#  'dt hvz': 0.0034342631241856053,
#  'wps in': 0.018698899767840917,
#  'pp ap': 0.007850105183089887,
#  'nns hv': 0.009934167192330076,
#  'vbg pn': 0.0037501117768040776,
#  'pn dt': 0.003823150881974411,
#  'vbg hvz': 0.00056447286059197,
#  'ben rb': 0.06881447519240215,
#  'wrb nns': 0.025891040948085253,
#  'hv rb': 0.0655275718492942,
#  'nn hvn': 6.597896590566928e-06,
#  'hvn jj': 0.05045871559633027,
#  'ppo cc': 0.061376153481416645,
#  'wps rb': 0.04267184818814979,
#  'rp hvz': 0.00018497343108898906,
#  'np wdt': 0.0033573128717405308,
#  'md nns': 0.0006161663801366216,
#  'pp np': 0.007434126861502989,
#  'jj ex': 0.0003999126390102236,
#  'ex hvz': 0.014286985935552785,
#  'jj ql': 0.0019641465775741976,
#  'jj fw': 0.0006065095742922579,
#  'fw fw': 0.4948309812930752,
#  'fw nn': 0.03536265178864457,
#  'rb hvz': 0.0025138947791343937,
#  'ben ql': 0.03688390371704601,
#  'ql in': 0.019196098372781065,
#  'dt jjs': 0.00023189558073279006,
#  'bez nr': 0.000992160946187548,
#  'nr jjr': 0.0015673981191222572,
#  'jjr in': 0.03942851373182552,
#  'vbn dti': 0.002300613496932515,
#  'in <END>': 0.0014193252555775111,
#  'at nr': 0.004519500865957173,
#  'nr dt': 0.005106684194559612,
#  'rb rb': 0.03808787750273431,
#  'vbn pp': 0.012232777492500204,
#  'rb ben': 0.006085243632954621,
#  'cs to': 0.006986146348586343,
#  'nn ppl': 0.0009303034192699367,
#  'vbd dti': 0.003314921431298156,
#  'in cc': 0.002582165819414984,
#  'cc wrb': 0.007804179269799344,
#  'cc hvz': 0.0017333745154006729,
#  'nn jjt': 0.00016854626744993698,
#  'pps vb': 0.012224794734924004,
#  'cd rb': 0.014623898618514087,
#  'ap jjr': 0.001591685289033183,
#  'wrb vbn': 0.022132307420182185,
#  'vbn md': 0.002199264884732845,
#  'rb ql': 0.01130276109908261,
#  'bez ap': 0.009342030295290673,
#  'be dti': 0.0052499682781372925,
#  'dti ql': 0.007273855488141203,
#  'rp at': 0.11453218537700949,
#  'in beg': 0.0013945839669852243,
#  'vbg np': 0.015654341411070378,
#  'nns vbz': 0.004183816072405633,
#  'dti jj': 0.15861141753998897,
#  'vb abl': 0.0010165510004531253,
#  'bez to': 0.02712234032102792,
#  'at fw': 0.0018165721151590442,
#  'in vb': 0.0005451330586500493,
#  'bez dt': 0.01199434173559402,
#  'beg at': 0.10804899387576553,
#  'ap to': 0.014030020660285872,
#  'vbz wrb': 0.0077946819072151115,
#  'jj hv': 0.00010477416003588883,
#  'hv np': 0.003325886056667005,
#  'nn od': 0.00019853670649796847,
#  'od jj': 0.05265877489665539,
#  'nns ben': 0.00019342090130654947,
#  'vbz bez': 0.004440687971236148,
#  'bez nn': 0.02240711998271086,
#  'pps doz': 0.008312431667631359,
#  'ap nps': 0.0042269258337901084,
#  'np vb': 0.00767043487984494,
#  'cs nps': 0.0016016573274681952,
#  'nps vb': 0.05008210180623973,
#  'vb ppls': 0.0034014213827478473,
#  'ppls in': 0.24688208616780044,
#  'nps cs': 0.028437080161218094,
#  'ppss hvd': 0.03994023370497427,
#  'vbd bedz': 0.002535856465070622,
#  'bedz cs': 0.013922134249882362,
#  'bedz jjr': 0.00430655291638536,
#  'nps dti': 0.0015673981191222572,
#  'rb hv': 0.005164505256579094,
#  'vbz <END>': 0.026979527221014783,
#  'dti jjr': 0.006929123000551572,
#  'rb dti': 0.0021790808240887477,
#  'vbn abx': 0.0008141671846706846,
#  'abx in': 0.131429344883595,
#  'vbn ql': 0.008719358936244967,
#  'vb ql': 0.0120763873983449,
#  'ql rbr': 0.02208533653846154,
#  'rbr cs': 0.13383881410802523,
#  'md in': 0.00951634742655449,
#  'rb ex': 0.004801790138612977,
#  'cc to': 0.007910684616367741,
#  'ppo cs': 0.05654338549075392,
#  'dti cd': 0.02244208494208494,
#  'hvd ql': 0.004331937258766527,
#  'nns hvd': 0.005386162215662562,
#  'rb dod': 0.0028487087341800403,
#  'ap vbg': 0.0076000337310789725,
#  'bedz dti': 0.0020560977106732956,
#  'hvd dti': 0.004537242342120391,
#  'np wpo': 0.00040202556989121346,
#  'hvd to': 0.05339985218033999,
#  'at abn': 0.00043960841192226173,
#  'abn rb': 0.01452254195026619,
#  'hv ap': 0.012973494465319386,
#  'cd dt': 0.0054457195692374635,
#  'rb abn': 0.0033509296667485096,
#  'abn in': 0.14290046499090234,
#  'nr pps': 0.023814339164728488,
#  'cc pn': 0.0033842073872108374,
#  'pn rb': 0.09353471118177,
#  'jjt jj': 0.09236356497840596,
#  'rp abn': 0.004725230376000538,
#  'abn dt': 0.031033088483051415,
#  'ber at': 0.0666019680418886,
#  'np pps': 0.008362664337935772,
#  'in hvg': 0.0006688395016114826,
#  'hvg at': 0.23234072022160662,
#  'cd md': 0.005853638638094202,
#  'wdt to': 0.012062270798878262,
#  'do cc': 0.01430293730819816,
#  'wrb to': 0.024122225170248517,
#  'be dt': 0.002077782007359472,
#  'vbg wdt': 0.0034147813645712243,
#  'vbd hvz': 0.00019866156638802108,
#  'hvz to': 0.023184992691245736,
#  'md do': 0.016438710462657276,
#  'do pps': 0.004438842612889083,
#  'be to': 0.004456921710442837,
#  'in od': 0.0007183220787960558,
#  'vbz rp': 0.02630872843381899,
#  'vbg to': 0.03504761691853707,
#  'pp nr': 0.0032743436456340105,
#  'pp vbz': 0.00012479349647606937,
#  'vbz pp': 0.031943438246263646,
#  'vbg nr': 0.002352901725833855,
#  'bez pp': 0.013074913063125013,
#  'md ex': 0.00023581676276833669,
#  'ex be': 0.006720669396474986,
#  'be nn': 0.011752950133231823,
#  'vbg pps': 0.0049237682196190645,
#  'ben ap': 0.005362698542655968,
#  'abx at': 0.1002977801840823,
#  'cc dt': 0.010679823627146083,
#  'do nn': 0.007726874177992109,
#  'rb ber': 0.0024859936162139233,
#  'cs nr': 0.0008259258583240551,
#  'cc ber': 0.002505538278021556,
#  'rb nr': 0.002234883149929689,
#  'cs rb': 0.02081241900450837,
#  'ap abn': 0.001275456423662352,
#  'abn vb': 0.017218141384190307,
#  'ppss bedz': 0.023323595626072044,
#  'dt pps': 0.006857483601669649,
#  'bedz wrb': 0.0034882055688537006,
#  'wpo ppss': 0.15690946221919674,
#  'abx jj': 0.10571196534921494,
#  'vbd abx': 0.0007050537944359181,
#  'cc dtx': 0.00016242065351680651,
#  'dtx vbd': 0.03700361010830325,
#  'ppo wrb': 0.010586497428602692,
#  'vb wrb': 0.008737568863132289,
#  'vbn bez': 0.0022330477554660683,
#  'cs wdt': 0.002559913848175662,
#  'wdt bez': 0.06814913352987705,
#  'vbz nr': 0.0017574928224529769,
#  'vbz nns': 0.01986906007673938,
#  'be ap': 0.006360233472909529,
#  'hvz in': 0.011815819392561312,
#  'vbg abx': 0.000508584458553161,
#  'nr cs': 0.032915360501567396,
#  'nns wrb': 0.0060483238597750745,
#  'dt ppss': 0.00663663066763842,
#  'vb ppss': 0.012136009157902267,
#  'ppo pps': 0.02171098223729803,
#  'ppo wdt': 0.005936098041361199,
#  'wdt bed': 0.008646724671028979,
#  'nr jj': 0.019769440792800082,
#  'pn hvz': 0.013286395639336816,
#  'jj abn': 0.0004146695629589403,
#  'ppo np': 0.018610715979137032,
#  'wdt ppss': 0.1005069389516071,
#  '<START> nr': 0.0013604238100922452,
#  'vbn ppss': 0.00402353990432691,
#  'bez pn': 0.007180887640228688,
#  'pn vbn': 0.014043455219925808,
#  'wrb md': 0.02544883700362607,
#  'md at': 0.008451368497923292,
#  'ppss bem': 0.014144243138936535,
#  'bem in': 0.029485049833887042,
#  'cc vbz': 0.009268627785114813,
#  'hv ppo': 0.012465725601706104,
#  'ppo abx': 0.0013768829558303242,
#  'np rbr': 0.0005351466195240656,
#  'rbr np': 0.022235474527176693,
#  'cs abn': 0.007214302663040502,
#  'abn nps': 0.0034031942853292,
#  'abn nn': 0.07551047914279937,
#  'ppo jj': 0.03046467520151731,
#  'wrb pn': 0.009971698947554612,
#  'pn vbg': 0.01290786584904232,
#  '<START> abl': 0.0007841474608852427,
#  'hv pp': 0.012973494465319386,
#  'nr np': 0.024319951461219538,
#  'np dti': 0.00042864977981778394,
#  'cc bez': 0.004156371149831721,
#  'vbd vbz': 0.00031552131132215114,
#  'vbn ppo': 0.018854220156211996,
#  'bez rbt': 0.0006974596750427317,
#  'rbt vbn': 0.26263537906137185,
#  'vbz dt': 0.010209557541119964,
#  'cd pps': 0.008301153051234635,
#  'wrb ppss': 0.15744671442469266,
#  'ppss pp': 0.00027471054888507715,
#  'ppss at': 0.004696880360205832,
#  'jj ppss': 0.0028200481665997686,
#  'ppss nps': 0.0003417131217838765,
#  'cc wdt': 0.0051415456055894,
#  'vbz nps': 0.0004158952480613915,
#  'nps np': 0.012016718913270639,
#  '<START> to': 0.004447618537986902,
#  'dod in': 0.03178742599379758,
#  'nps at': 0.03814002089864159,
#  'vbz vbz': 0.0029649306394054042,
#  'vbz cc': 0.01986906007673938,
#  'cd bez': 0.006737463287283803,
#  'ppo vbg': 0.01651347703979283,
#  'nns ex': 0.0016571466409236804,
#  'vbz pps': 0.008197161179532588,
#  'nps <END>': 0.10979250634423048,
#  'ppss be': 0.005232900943396226,
#  'in wrb': 0.0009574878685214935,
#  'rb dt': 0.007284993638534854,
#  'nns wp': 0.0010821115289312362,
#  'wp jj': 0.14280215550423403,
#  'be vbg': 0.03173772363913209,
#  'rp nr': 0.003211811394363355,
#  'jj nps': 0.002333069676292116,
#  'nps vbd': 0.08441558441558442,
#  'ben vbg': 0.08887342393974128,
#  'dti vbd': 0.0034817981246552674,
#  'dts vb': 0.007043413790262789,
#  'vb ex': 0.0010463618802318093,
#  'rp abl': 0.0005212887603416964,
#  'hv pn': 0.009672996851833045,
#  'pn jj': 0.058709970474676354,
#  'ber abn': 0.009050284373025188,
#  'bez rp': 0.002563901058959901,
#  'rp <END>': 0.0992298378960113,
#  'vbg bez': 0.0034706697666100333,
#  'wps bed': 0.02475522357928737,
#  'ap uh': 0.00011595058396930474,
#  'uh <END>': 0.06608437705998682,
#  'ber nns': 0.03297372934910174,
#  'jjr bez': 0.002069870759289176,
#  'nn dti': 0.0007563588727913541,
#  'hvg vbn': 0.29813019390581713,
#  'nps cc': 0.1232273473652784,
#  'wrb vbz': 0.0009065180861413283,
#  'wrb cd': 0.0066551693641107275,
#  'ber np': 0.00679335560169721,
#  'dts bed': 0.014045638026196556,
#  'nns dt': 0.0031557229933888383,
#  'wrb do': 0.010192800919784204,
#  'do ppss': 0.08883165278386672,
#  'vbz ppss': 0.006453084332823526,
#  'do vb': 0.33872205173169667,
#  'md jj': 0.0013007956913995346,
#  'md <END>': 0.005560711405924326,
#  'vbz abn': 0.005648125788188575,
#  'abn vbg': 0.010816092728620526,
#  'vbg vb': 0.001794017705445766,
#  'vbd pn': 0.004950957860375977,
#  'pn ppss': 0.019342872284048754,
#  'hvd np': 0.0061796830089513016,
#  '<START> vbn': 0.005888309411004409,
#  'jj dt': 0.0008721342053691592,
#  'cd ber': 0.002250353529859676,
#  'at pn': 0.001510580181106426,
#  'pn bedz': 0.020478461654932244,
#  'dt vbg': 0.00740961593674772,
#  'hvd at': 0.0885070214338507,
#  'wdt ber': 0.027701876752714457,
#  'ber to': 0.012887063284282747,
#  'nns dod': 0.0012215139803233438,
#  'dod jj': 0.005004228925852833,
#  'ber beg': 0.00972736300442358,
#  'pn md': 0.08482852600499659,
#  'nns dti': 0.0007858813197230073,
#  'dti at': 0.0014134031991174846,
#  'cc abn': 0.003836855110126528,
#  'rp to': 0.02877177641756911,
#  'hvd dt': 0.003305411841997208,
#  'ppo dod': 0.0009209614472772368,
#  'ber ap': 0.02033492822966507,
#  'wdt doz': 0.004512116200474581,
#  'doz cd': 0.0018972059330803728,
#  'cd vb': 0.004833840965952355,
#  'vbn ppl': 0.0015911732115348235,
#  'rb wdt': 0.004383272694805919,
#  'dti vb': 0.0048607280750137885,
#  'hvz hvn': 0.011003735585512424,
#  'hvn ql': 0.029608006672226853,
#  'ap wps': 0.0021187333979845683,
#  'cs md': 0.001966707430594849,
#  'md np': 0.0016811453087678197,
#  'rb pn': 0.003629941295953215,
#  'hvd in': 0.012954750759628809,
#  'cd ql': 0.0030661916675731537,
#  'np hv': 0.0016533634364400236,
#  'ber cs': 0.00589058409316602,
#  'wps dod': 0.01087614817805592,
#  'jj qlp': 0.00245112506788185,
#  'qlp at': 0.019406392694063926,
#  'cd bedz': 0.006329544218427064,
#  'rp dti': 0.005397861034505953,
#  'be rp': 0.003188047202131709,
#  'pn bez': 0.02918464683170565,
#  'md ql': 0.00396324301297753,
#  'md cc': 0.005104291865082384,
#  'cc hv': 0.0017600008520427723,
#  'in dtx': 0.00035544984610918497,
#  'dtx nn': 0.3528880866425993,
#  'ap vb': 0.0035944681030484465,
#  'rp pps': 0.011956009954933745,
#  'ppls <END>': 0.13350340136054423,
#  ...}

# %% [markdown]
# ## 4.3
# An emission probability is the probability of a given word being associated with a given tag.

# %%
## emission probability is the probability of a given word being associated with a given tag
prob_emission = {}
lambda_val = 0.1
smoothed_prob_emission = {}
for i in counter_word_tag:
    if i not in  ["<START>", "<END>"]:
        tag_of_word = i.split("/")[1]
        prob_emission[i] = (counter_word_tag[i] + lambda_val)/(counter_tag[tag_of_word] + (lambda_val * len(counter_word_tag)))
        smoothed_prob_emission[tag_of_word] = (lambda_val)/((counter_tag[tag_of_word] +lambda_val * len(counter_word_tag)))

# %%
prob_emission
# Out:
# {'The/at': 0.07181598895246241,
#  'Fulton/np': 0.00043187707414647455,
#  'County/nn': 0.0005042825499275279,
#  'Grand/jj': 0.000216333617957696,
#  'UNK/nn': 0.08668859989594357,
#  'said/vbd': 0.06125255354319909,
#  'Friday/nr': 0.014728604894582066,
#  'an/at': 0.03493424037187514,
#  'investigation/nn': 0.0002494746809864738,
#  'of/in': 0.2900252738268272,
#  's/np': 0.06551650982709764,
#  'recent/jj': 0.0023939965272007286,
#  'primary/nn': 0.00010133057113702383,
#  'election/nn': 0.00043909914159376984,
#  'produced/vbd': 0.0010141987829614606,
#  'no/at': 0.015349242480260119,
#  'evidence/nn': 0.00117981969084102,
#  'that/cs': 0.26497728563316303,
#  'any/dti': 0.2575370775589594,
#  'irregularities/nns': 0.00013631177363494697,
#  'took/vbd': 0.015090267300931909,
#  'place/nn': 0.0027857018416090583,
#  'jury/nn': 0.00037391573326001185,
#  'further/rbr': 0.027769120488686648,
#  'in/in': 0.15346874351121262,
#  'end/nn': 0.0021753481090293243,
#  'UNK/nns': 0.13806363235536648,
#  'the/at': 0.6201059988049153,
#  'City/nn': 0.0007887192408384719,
#  'Executive/jj': 7.306632129697017e-05,
#  'Committee/nn': 0.0005220598431094619,
#  'which/wdt': 0.46160629672528164,
#  'had/hvd': 0.6852554448563485,
#  'all/jj': 0.0005171949409452203,
#  'charge/nn': 0.0006227978378070878,
#  'deserves/vbz': 0.0016967729696688659,
#  'praise/nn': 7.762751356111182e-05,
#  'and/cc': 0.697978864203518,
#  'thanks/nns': 0.00045605544018605717,
#  'Atlanta/np': 0.0008864845206164477,
#  'for/in': 0.06793841491901993,
#  'manner/nn': 0.0007294615968986919,
#  'was/bedz': 0.8110595566694325,
#  'conducted/vbn': 0.0012991692902932141,
#  'October/np': 0.0013663479363347527,
#  'term/nn': 0.0007353873612926699,
#  'been/ben': 0.5427237805967482,
#  'charged/vbn': 0.0012675593318919192,
#  'by/in': 0.04062873105274086,
#  'Superior/jj': 0.00023066034762376863,
#  'Court/nn': 0.0006524266597769778,
#  'Judge/nn': 0.00022577162341056185,
#  'UNK/np': 0.23228167477383282,
#  'to/to': 0.8634766714538356,
#  'investigate/vb': 0.00031197652587437746,
#  'reports/nns': 0.0010787141592592717,
#  'possible/jj': 0.005302322649413464,
#  'fought/jj': 3.0086132298752428e-05,
#  'won/vbn': 0.0006985800806686139,
#  'Allen/np': 0.0005076449818914701,
#  'Only/rb': 0.0024580468692245137,
#  'a/at': 0.21633528717002773,
#  'relative/jj': 0.0006174820486077283,
#  'handful/nn': 7.762751356111182e-05,
#  'such/jj': 0.012809528994435498,
#  'received/vbn': 0.0030693269607657194,
#  'considering/in': 0.00012247586171096344,
#  'widespread/jj': 0.0004169078332827122,
#  'interest/nn': 0.0019086887113003142,
#  'number/nn': 0.0027442214908512124,
#  'voters/nns': 0.000304597913925005,
#  'size/nn': 0.0008242738272023399,
#  'this/dt': 0.3531008241213279,
#  'city/nn': 0.001570920140843568,
#  'it/pps': 0.18300827308926432,
#  'did/dod': 0.2777102154273801,
#  'find/vb': 0.010936042001596421,
#  'many/ap': 0.0769077211498403,
#  'registration/nn': 0.00013688515750089183,
#  'laws/nns': 0.0014994295099844167,
#  'are/ber': 0.6666202672605791,
#  'UNK/jj': 0.09783866956257628,
#  'or/cc': 0.10330726719809252,
#  'inadequate/jj': 0.00045988802228092996,
#  'often/rb': 0.00913780903800864,
#  'ambiguous/jj': 0.0003309474552862767,
#  'It/pps': 0.09694301619824487,
#  'recommended/vbd': 0.0006171814657879351,
#  'legislators/nns': 0.0002709406858669934,
#  'act/vb': 0.0020545481118393687,
#  'have/hv': 0.6413385563144502,
#  'these/dts': 0.2725092995114955,
#  'studied/vbn': 0.001425609123898393,
#  'revised/vbn': 0.00028765062145178215,
#  'to/in': 0.08818343153031562,
#  'UNK/vbg': 0.16625684979626248,
#  'improving/vbg': 0.0008079246873682733,
#  'them/ppo': 0.1329144105340881,
#  'grand/jj': 0.00043123456294878477,
#  'commented/vbd': 0.0005810889824085237,
#  'on/in': 0.04672008020141196,
#  'other/ap': 0.13931224829884736,
#  'topics/nns': 0.00016996900169295856,
#  'among/in': 0.002450328332641196,
#  'purchasing/vbg': 0.0006573797145667316,
#  'departments/nns': 0.0004223982121280456,
#  'well/ql': 0.006465436580710355,
#  'operated/vbn': 0.0006037502054647297,
#  'follow/vb': 0.0024761380116696085,
#  'generally/rb': 0.003065297975477616,
#  'accepted/vbn': 0.0020894182503255823,
#  'practices/nns': 0.0008262849488241847,
#  'UNK/vb': 0.060149636308446414,
#  'best/jjt': 0.09303772596279801,
#  'both/abx': 0.23114364003461205,
#  'governments/nns': 0.0008599421768821964,
#  'proposed/vbn': 0.0019945883751216983,
#  'However/wrb': 0.0035226302305721604,
#  'believes/vbz': 0.0045422928566911875,
#  'two/cd': 0.07878234071525837,
#  'offices/nns': 0.0006579988085341268,
#  'should/md': 0.056789586709352725,
#  'be/be': 0.7508873327257902,
#  'combined/vbn': 0.001046289623082856,
#  'achieve/vb': 0.0014362162587550171,
#  'greater/jjr': 0.04485008466978782,
#  'efficiency/nn': 0.00028502926735034185,
#  'reduce/vb': 0.001745382185297193,
#  'cost/nn': 0.0011264878112952179,
#  'administration/nn': 0.0006109463090191319,
#  'Department/nn': 0.00097241793705179,
#  'is/bez': 0.8156714096245476,
#  'lacking/vbg': 0.001309741263373412,
#  'experienced/vbn': 0.0013623892070958035,
#  'clerical/jj': 0.0001303732399612605,
#  'personnel/nns': 0.0011123713873172833,
#  'as/cs': 0.23019591141396936,
#  'result/nn': 0.001162042397659086,
#  'policies/nns': 0.0011123713873172833,
#  'urged/vbd': 0.0007254589159261693,
#  'take/vb': 0.015798378846305187,
#  'steps/nns': 0.0019201448607095617,
#  'remedy/vb': 8.712857929824957e-05,
#  'problem/nn': 0.0018079507166026882,
#  'automobile/nn': 0.00025540044538045184,
#  'title/nn': 0.00030873232492625386,
#  'law/nn': 0.0017131384862990402,
#  'also/rb': 0.026325655567172535,
#  'recommended/vbn': 0.0009198497894776772,
#  'outgoing/jj': 0.00011604651029518792,
#  'next/ap': 0.02500520761005416,
#  'Legislature/nn': 0.00016058821507680383,
#  'provide/vb': 0.006017493170243623,
#  'enabling/vbg': 0.0006573797145667316,
#  'funds/nns': 0.0015162581240134225,
#  'set/vb': 0.0024761380116696085,
#  'effective/jj': 0.0018352540702238978,
#  'date/nn': 0.0005694659582612859,
#  'so/cs': 0.017332231018472127,
#  'orderly/jj': 0.0002736405366219864,
#  'implementation/nn': 3.0221398409287804e-05,
#  'may/md': 0.08471997154262677,
#  'effected/vbn': 0.00035087053825437166,
#  'at/in': 0.039841965583471764,
#  'State/nn': 0.0015590686120556122,
#  'Welfare/nn': 4.207292719724381e-05,
#  's/nn': 0.011366208684089203,
#  'handling/nn': 0.00014873668628884783,
#  'federal/jj': 0.0016060263955667365,
#  'granted/vbn': 0.0014572190822996877,
#  'child/nn': 0.001245003099174778,
#  'welfare/nn': 0.00028502926735034185,
#  'services/nns': 0.002138916843086637,
#  'homes/nns': 0.0010282283171722543,
#  'This/dt': 0.10523326059906586,
#  'one/cd': 0.14226928498052988,
#  'major/jj': 0.0031819666588347208,
#  'items/nns': 0.0011965144574623123,
#  'general/jj': 0.004170511005793729,
#  'assistance/nn': 0.0005042825499275279,
#  'program/nn': 0.002169422344635346,
#  'but/cc': 0.07072459814708171,
#  'has/hvz': 0.5369752757025968,
#  'seen/vbn': 0.0086010696809923,
#  'fit/jj': 0.00011604651029518792,
#  'distribute/vb': 0.0001714465592642975,
#  'through/in': 0.007016812448089701,
#  'all/abn': 0.49896054051893013,
#  'counties/nns': 0.0005233698963020804,
#  'state/nn': 0.0031827280560055844,
#  'with/in': 0.056291041580149505,
#  'exception/nn': 0.00023762315219851785,
#  'receives/vbz': 0.0021183314714499505,
#  'none/pn': 0.018838472394474615,
#  'money/nn': 0.001541291318873678,
#  'they/ppss': 0.16038703743012808,
#  'realize/vb': 0.0019421241385513047,
#  'proportionate/jj': 0.0001303732399612605,
#  'distribution/nn': 0.0004983567855335498,
#  'might/md': 0.04256090009617538,
#  'our/pp': 0.06023029698981053,
#  'less/ql': 0.016570605187319884,
#  'populous/jj': 7.306632129697017e-05,
#  'Nevertheless/rb': 0.0010851313246522827,
#  'we/ppss': 0.11457227764805775,
#  'feel/vb': 0.005539691283769351,
#  'future/nn': 0.0007827934764444939,
#  'receive/vb': 0.0021388660918054167,
#  'some/dti': 0.2780006483507577,
#  'portion/nn': 0.0003679899688660339,
#  'available/jj': 0.0034111943334918823,
#  'do/do': 0.3202663488444398,
#  'will/md': 0.13761643149809624,
#  'continue/vb': 0.00295393989814388,
#  'place/vb': 0.001492428245399049,
#  'burden/nn': 0.00025540044538045184,
#  'taxpayers/nns': 0.0003382551419830166,
#  'court/nn': 0.0006998327749288019,
#  'under/in': 0.005086398203903654,
#  'fire/nn': 0.001013898287809636,
#  'its/pp': 0.09368273726845716,
#  'appointment/nn': 0.00015466245068282585,
#  'administrators/nns': 8.582593154792957e-05,
#  'fees/nns': 0.00045605544018605717,
#  'compensation/nn': 0.00010133057113702383,
#  'protected/vbn': 0.0008250199142737929,
#  'found/vbd': 0.009568117343881964,
#  'incorporated/vbn': 0.00035087053825437166,
#  'into/in': 0.014251810371677739,
#  'operating/vbg': 0.004119914089002188,
#  'procedures/nns': 0.0010282283171722543,
#  'recommendations/nns': 0.00035508375601202237,
#  'previous/jj': 0.0010472839385899059,
#  'Bar/nn': 6.57759847731558e-05,
#  'Association/nn': 0.0005102083143215058,
#  'interim/nn': 3.0221398409287804e-05,
#  'citizens/nns': 0.0012806575276073412,
#  'committee/nn': 0.00046280219916968184,
#  'These/dts': 0.07665934656926456,
#  'actions/nns': 0.0011123713873172833,
#  'serve/vb': 0.0028415159248558162,
#  'protect/vb': 0.0009584143722807452,
#  'fact/nn': 0.0026197804385776746,
#  'effect/nn': 0.001162042397659086,
#  'from/in': 0.03375872741901993,
#  'undue/jj': 0.00018768015862555084,
#  'costs/nns': 0.0026942611060438285,
#  'appointed/vbn': 0.0010778995814841508,
#  'elected/vbn': 0.001046289623082856,
#  'servants/nns': 0.0003719123700410282,
#  'criticisms/nns': 0.00018679761572196437,
#  'UNK/in': 0.0005766909779900332,
#  'new/jj': 0.015087479011341037,
#  'dollar/jj': 0.00011604651029518792,
#  'airport/nn': 6.57759847731558e-05,
#  'when/wrb': 0.26306880566060753,
#  'management/nn': 0.0005813174870492419,
#  'takes/vbz': 0.008863267499947305,
#  '1/cd': 0.03428772784825247,
#  'that/wps': 0.2714585834333733,
#  'eliminate/vb': 0.0007054604323826014,
#  'political/jj': 0.003712055656479407,
#  'influences/nns': 0.00018679761572196437,
#  'elaborate/vb': 0.0001714465592642975,
#  'added/vbd': 0.002927100402070265,
#  'there/ex': 0.31088845291479816,
#  'periodic/jj': 0.00011604651029518792,
#  'surveillance/nn': 3.61471628032658e-05,
#  'pricing/vbg': 0.0002559264537626207,
#  'concessionaires/nns': 0.00010265454557693536,
#  'purpose/nn': 0.000859828413566208,
#  'keeping/vbg': 0.0026646460185872863,
#  'prices/nns': 0.0010282283171722543,
#  'reasonable/jj': 0.0009183433715952526,
#  'Ask/vb': 0.00034008251919639347,
#  'jail/nn': 0.00010133057113702383,
#  'deputies/nns': 0.00022045484377997596,
#  'On/in': 0.002758545732973422,
#  'matters/nns': 0.000977742475085237,
#  'Four/cd': 0.002215771996464321,
#  'additional/jj': 0.0015200660175703012,
#  'employed/vbn': 0.0013623892070958035,
#  'doctor/nn': 0.0005161340787154838,
#  'medical/jj': 0.0017206402328953172,
#  'night/nn': 0.0023175664544847962,
#  'weekend/nn': 0.00016058821507680383,
#  'duty/nn': 0.00035021267568409984,
#  '2/cd': 0.028972264029241027,
#  'work/vb': 0.004893253437362984,
#  'officials/nns': 0.0009440852470272254,
#  'pass/vb': 0.001745382185297193,
#  'legislation/nn': 0.00026132620977442985,
#  'permit/vb': 0.0018297001652632407,
#  'establishment/nn': 0.00030873232492625386,
#  'fair/jj': 0.0008610364529309623,
#  'equitable/jj': 0.00015902669929340567,
#  'pension/nn': 7.170174916713382e-05,
#  'plan/nn': 0.00097241793705179,
#  'employes/nns': 0.00025411207183798757,
#  'praised/vbd': 0.00029234911537323236,
#  'operation/nn': 0.0006998327749288019,
#  'Police/nns': 0.0003382551419830166,
#  'Tax/nn': 5.985022037917781e-05,
#  'Office/nn': 0.00024354891659249584,
#  'prison/nn': 0.00024354891659249584,
#  'farms/nns': 0.0002709406858669934,
#  'Grady/np': 0.0001288054431664924,
#  'Hospital/nn': 0.00020799433022862784,
#  'Health/nn': 0.00010133057113702383,
#  'Mayor/nn': 0.00017836550825873785,
#  'William/np': 0.003715153076429614,
#  'Hartsfield/np': 0.0001288054431664924,
#  'filed/vbd': 0.0004006265655114666,
#  'suit/nn': 0.00023762315219851785,
#  'divorce/nn': 0.00011318209992497983,
#  'his/pp': 0.33776361689268714,
#  'wife/nn': 0.001345741093872404,
#  'Pearl/np': 5.3037535421496873e-05,
#  'Williams/np': 0.0008107166128714522,
#  'His/pp': 0.027626096084315,
#  'petition/nn': 8.355327795508982e-05,
#  'charged/vbd': 0.0006171814657879351,
#  'mental/jj': 0.0005601751299434381,
#  'cruelty/nn': 7.762751356111182e-05,
#  'couple/nn': 0.0007116843037167579,
#  'married/vbn': 0.0024687377511411193,
#  '1913/cd': 0.0007226641821352637,
#  'They/ppss': 0.0491226208165287,
#  'son/nn': 0.0008361253559902959,
#  'Berry/np': 0.00015406141241482423,
#  'daughter/nn': 0.00042724761280581386,
#  'Griffin/np': 0.00015406141241482423,
#  'mayor/nn': 5.392445598519981e-05,
#  'property/nn': 0.000889457235536098,
#  'settlement/nn': 0.00014873668628884783,
#  'agreed/vbn': 0.0008882398310763824,
#  'upon/rb': 0.001164337990685296,
#  'listed/vbd': 0.0004006265655114666,
#  'occupation/nn': 0.00013688515750089183,
#  'attorney/nn': 0.00015466245068282585,
#  'age/nn': 0.00126870615675069,
#  '71/cd': 0.0006032155569889391,
#  '74/cd': 0.0003643183066962899,
#  'birth/nn': 0.00037391573326001185,
#  'lived/vbn': 0.0012991692902932141,
#  'together/rb': 0.006840815723051253,
#  'man/nn': 0.006702632106028517,
#  'more/ap': 0.08098701569226496,
#  'than/in': 0.004015748286960133,
#  'year/nn': 0.0038404879037371425,
#  'home/nr': 0.07478941334795394,
#  'UNK/cd': 0.05543013449915192,
#  'Pelham/np': 0.0001288054431664924,
#  'Aj/nn': 0.0006346493665950439,
#  'Henry/np': 0.002124027013784708,
#  'listed/vbn': 0.0009830697062802665,
#  'brief/jj': 0.0008896899122631074,
#  'since/in': 0.001201236762873754,
#  '1937/cd': 0.0006032155569889391,
#  'career/nn': 0.00039761879083592385,
#  'goes/vbz': 0.009179436376283118,
#  'back/rb': 0.018616206739959236,
#  'council/nn': 0.00016058821507680383,
#  '1923/cd': 0.00042404261926945225,
#  'present/jj': 0.0032249468478329386,
#  'office/nn': 0.001274631921144668,
#  'UNK/vbz': 0.1214193874754969,
#  'He/pps': 0.14159450264816176,
#  'succeeded/vbn': 0.0004457004134582559,
#  'who/wps': 0.3631619314392423,
#  'became/vbd': 0.008774082709534912,
#  'candidate/nn': 0.00019021703704669385,
#  '13/cd': 0.0031713609976349176,
#  'after/cs': 0.011110832748772424,
#  'announced/vbd': 0.0018443259006879229,
#  'he/pps': 0.31048730042138634,
#  'would/md': 0.17114606800785212,
#  'run/vb': 0.003347423804652104,
#  'Georgia/np': 0.001164300182348098,
#  'Republicans/nps': 0.008623244236353939,
#  'getting/vbg': 0.007632630121038158,
#  'strong/jj': 0.0026805311205221802,
#  'encouragement/nn': 8.355327795508982e-05,
#  'enter/vb': 0.0023356080450595285,
#  '1962/cd': 0.0020963233713179965,
#  'race/nn': 0.0005635401938673079,
#  'top/jjs': 0.027674667986471987,
#  'official/nn': 0.00011910786431895783,
#  'Wednesday/nr': 0.008747445546528435,
#  'Robert/np': 0.002073515075288044,
#  'GOP/nn': 7.762751356111182e-05,
#  'chairman/nn': 0.00029095503174431987,
#  'meeting/nn': 0.0007294615968986919,
#  'held/vbn': 0.00420728546321233,
#  'Tuesday/nr': 0.014479389921746497,
#  'Blue/jj': 0.000631808778273801,
#  'Ridge/nn': 3.61471628032658e-05,
#  'brought/vbd': 0.004840002021179069,
#  'enthusiastic/jj': 0.0003452741849523493,
#  'responses/nns': 0.0004392268261570514,
#  'audience/nn': 0.0006761297173528899,
#  'Party/nn': 0.00012503362871293583,
#  'Chairman/nn': 0.00011318209992497983,
#  'James/np': 0.002553378491006349,
#  'enthusiasm/nn': 0.00016058821507680383,
#  'picking/vbg': 0.0006573797145667316,
#  'up/rp': 0.20874260799839628,
#  'rally/nn': 3.0221398409287804e-05,
#  '8/cd': 0.007590960128048926,
#  'Savannah/np': 0.00022982932015981977,
#  'newly/rb': 0.0006626957724762116,
#  'Texas/np': 0.0017451874750597303,
#  'John/np': 0.009069418557075966,
#  'featured/vbn': 0.00016121078784660318,
#  'speaker/nn': 0.00014281092189486982,
#  'In/in': 0.014503250882475081,
#  'warned/vbn': 0.0002560406630504874,
#  'entering/vbg': 0.0012093779481723841,
#  'governor/nn': 0.0002731777385623858,
#  'force/vb': 0.0006773544390605853,
#  'it/ppo': 0.21582728279596355,
#  'petitions/nns': 0.00010265454557693536,
#  'out/rp': 0.19984714844141524,
#  'voting/vbg': 0.0010588329753708427,
#  'precincts/nns': 8.582593154792957e-05,
#  'obtain/vb': 0.0011832623188568732,
#  'signatures/nns': 8.582593154792957e-05,
#  'registered/vbn': 0.00047731037185955063,
#  'Despite/in': 0.0003090284987541528,
#  'warning/vbg': 0.001309741263373412,
#  'unanimous/jj': 7.306632129697017e-05,
#  'vote/nn': 0.00029095503174431987,
#  'according/in': 0.000803798536129568,
#  'attended/vbd': 0.0008698288494438149,
#  'When/wrb': 0.08815725265340978,
#  'crowd/nn': 0.00028502926735034185,
#  'asked/vbn': 0.0026583975015488878,
#  'whether/cs': 0.010651534889935532,
#  'wanted/vbd': 0.007330383374358456,
#  'wait/vb': 0.0018297001652632407,
#  'make/vb': 0.021110411584166208,
#  'voted/vbd': 0.0007976438826849922,
#  'no/rb': 0.0017979913189494028,
#  'were/bed': 0.6084155235611985,
#  'largest/jjt': 0.01738931097720723,
#  'face/vb': 0.0014362162587550171,
#  'says/vbz': 0.020350736673481862,
#  'before/cs': 0.016538898353208407,
#  'making/vbg': 0.011446436098677211,
#  'first/od': 0.22555000480353538,
#  'alternative/jj': 0.0001303732399612605,
#  'courses/nns': 0.0009609138610562312,
#  'must/md': 0.065221400998643,
#  'taken/vbn': 0.008790729431400069,
#  'Five/cd': 0.002633842184476457,
#  'per/in': 0.002993764275332226,
#  'cent/nn': 0.0009250118218999659,
#  'each/dt': 0.06736335274917497,
#  'county/nn': 0.00041539608401785783,
#  'sign/vb': 0.0005087184791284894,
#  'requesting/vbg': 0.0004064714265641623,
#  'allowed/vbn': 0.0020578082919242876,
#  'names/nns': 0.0014994295099844167,
#  'candidates/nns': 0.000641170194505121,
#  'ballot/nn': 7.170174916713382e-05,
#  'hold/vb': 0.003769013704482344,
#  'unit/nn': 0.0005516886650793519,
#  'system/nn': 0.0023175664544847962,
#  'party/nn': 0.001138339340083174,
#  'platform/nn': 0.00041539608401785783,
#  'Sam/np': 0.0019977471675430487,
#  'Highway/nn': 4.799869159122181e-05,
#  'public/jj': 0.003812342764141915,
#  'relations/nns': 0.0015667439661004399,
#  'director/nn': 0.0004568764347757038,
#  'resigned/vbd': 0.00025625663199382095,
#  'Garland/np': 0.00020457335091148793,
#  'campaign/nn': 0.00043909914159376984,
#  'resignation/nn': 4.207292719724381e-05,
#  'expected/vbn': 0.004934314506442109,
#  'time/nn': 0.00912034397877154,
#  'Rob/np': 0.00043187707414647455,
#  'assistant/nn': 0.00010133057113702383,
#  'three/cd': 0.03369048472252085,
#  'years/nns': 0.015584979452262272,
#  'gubernatorial/jj': 0.00010171978062911534,
#  'starts/vbz': 0.0022237210968952216,
#  'become/vb': 0.006551507043361927,
#  'coordinator/nn': 3.0221398409287804e-05,
#  'Byrd/np': 0.00025508528940815163,
#  'wind/vb': 0.00019955255258631352,
#  '1961/cd': 0.008068754628634225,
#  'session/nn': 0.00046872796356365985,
#  'Monday/nr': 0.016971539650102174,
#  'head/vb': 0.0003681885125184094,
#  'where/wrb': 0.12811089422959618,
#  'highway/nn': 0.00019021703704669385,
#  'bond/nn': 0.00025540044538045184,
#  'approved/vbd': 0.0004006265655114666,
#  'shortly/rb': 0.0006362935504652072,
#  'Before/in': 0.00017925275124584718,
#  'afternoon/nn': 0.0006227978378070878,
#  'Senate/nn': 0.00033836114689614387,
#  'approve/vb': 0.0003962945058404254,
#  'study/nn': 0.0011916712196289759,
#  'allotted/vbn': 0.0002560406630504874,
#  'rural/jj': 0.0006604622376059461,
#  'urban/jj': 0.0005888285892755832,
#  'areas/nns': 0.0039564071582192635,
#  'determine/vb': 0.0025604559916356565,
#  'what/wdt': 0.18533484258186794,
#  'adjustments/nns': 0.0003382551419830166,
#  'made/vbn': 0.02051802399828042,
#  'Vandiver/np': 0.00015406141241482423,
#  'traditional/jj': 0.0011045908572541961,
#  'visit/nn': 0.00035021267568409984,
#  'chambers/nns': 0.00013631177363494697,
#  'toward/in': 0.0030343191964285715,
#  'likely/rb': 0.0006626957724762116,
#  'mention/vb': 0.0009303083789587292,
#  '100/nns': 0.00020362622975097017,
#  'million/cd': 0.012189732196182423,
#  'issue/nn': 0.0007768677120505159,
#  'approved/vbn': 0.0008250199142737929,
#  'earlier/rbr': 0.020912547528517105,
#  'priority/nn': 0.00011318209992497983,
#  'item/nn': 0.00032650961810818784,
#  'Construction/nn': 3.61471628032658e-05,
#  'bonds/nns': 0.0007926277207661732,
#  'Meanwhile/rb': 0.0005570868844321939,
#  'learned/vbn': 0.0017733186663126353,
#  'very/ql': 0.06260526217298551,
#  'near/rb': 0.0005306846624211894,
#  'being/beg': 0.24079247224876862,
#  'ready/jj': 0.0019498679075524786,
#  'issue/vb': 0.0003962945058404254,
#  '30/nns': 5.216870348991798e-05,
#  'worth/nn': 0.00011318209992497983,
#  'reconstruction/nn': 4.799869159122181e-05,
#  'go/vb': 0.01683830059921978,
#  'courts/nns': 0.0007421418786791558,
#  'friendly/jj': 0.0008610364529309623,
#  'test/nn': 0.0005635401938673079,
#  'test/vb': 0.00048061248580647344,
#  'validity/nn': 8.947904234906782e-05,
#  'act/nn': 0.0005576144294733298,
#  'then/rb': 0.026325655567172535,
#  'sales/nns': 0.0021052596150286256,
#  'begin/vb': 0.0023075020517375126,
#  'contracts/nns': 0.0003382551419830166,
#  'let/vbn': 0.00012960082944530845,
#  'repair/nn': 8.947904234906782e-05,
#  'work/nn': 0.0034019813385827704,
#  'most/ql': 0.05942400538942326,
#  'heavily/rb': 0.0014019579887843362,
#  'traveled/vbn': 0.00028765062145178215,
#  'highways/nns': 0.00023728345780898178,
#  'A/at': 0.01184192908232294,
#  'source/nn': 0.0005279856075034398,
#  'there/rb': 0.0136525890018904,
#  '3/nns': 8.582593154792957e-05,
#  '4/nns': 0.00011948315960594117,
#  'Rural/jj': 0.00011604651029518792,
#  'Authority/nn': 5.985022037917781e-05,
#  'road/nn': 0.001102784753719306,
#  'construction/nn': 0.0005161340787154838,
#  'revolving/vbg': 0.00030610811136313457,
#  'fund/nn': 0.00025540044538045184,
#  'department/nn': 0.00035613844007807786,
#  'apparently/rb': 0.0026692646453125492,
#  'intends/vbz': 0.0006428767152161541,
#  'issued/vbn': 0.0009514597478789718,
#  'every/at': 0.004297707955705929,
#  'old/jj': 0.008955638714261973,
#  'ones/nns': 0.0018864876326515501,
#  'paid/vbn': 0.0029744970855618354,
#  'off/rp': 0.058772677157462164,
#  'tax/nn': 0.001102784753719306,
#  'authorities/nns': 0.0005906843524181036,
#  'opened/vbd': 0.00332411771924379,
#  '1958/cd': 0.005620057813134571,
#  'battle/nn': 0.00044502490598774785,
#  'against/in': 0.0049647334406146175,
#  'issuance/nn': 4.207292719724381e-05,
#  '50/nns': 0.000388740984070034,
#  'roads/nns': 0.0009272566329982196,
#  'Marvin/np': 0.00022982932015981977,
#  'told/vbd': 0.01025387452809078,
#  'Constitution/nn': 0.00022577162341056185,
#  'however/wrb': 0.013282298401854336,
#  'consulted/vbn': 0.00035087053825437166,
#  'yet/rb': 0.005705520176578061,
#  'about/in': 0.009888100861710962,
#  'plans/nns': 0.0016004011941584515,
#  'offer/vb': 0.0018859121519072726,
#  'resolution/nn': 0.00037391573326001185,
#  'House/nn': 0.00112056204690124,
#  'action/nn': 0.0017486930726629082,
#  'itself/ppl': 0.09215132346619173,
#  '10/nns': 0.00013631177363494697,
#  'day/nn': 0.0036804922650997365,
#  'increase/nn': 0.0006642781885649339,
#  'expense/nn': 0.00029095503174431987,
#  'allowances/nns': 0.0004223982121280456,
#  'Sunday/nr': 0.02494641878084035,
#  'research/nn': 0.0007827934764444939,
#  'done/vbn': 0.009770638141840206,
#  'can/md': 0.11278210347417097,
#  'UNK/vbn': 0.0910082312331677,
#  'outright/rb': 0.00010824911024511822,
#  'notice/nn': 0.00017243974386475984,
#  'first/rb': 0.0077120890494144,
#  'given/vbn': 0.011572405770714007,
#  'sought/vbn': 0.0006353601638660244,
#  'While/cs': 0.005014697531482781,
#  'technical/jj': 0.001620353125232809,
#  'details/nns': 0.0009440852470272254,
#  'fully/rb': 0.001745186874927394,
#  'worked/vbn': 0.0016468788327074562,
#  'seek/vb': 0.0019421241385513047,
#  'aside/rb': 0.0014811646548173495,
#  'privilege/nn': 0.00010725633553100183,
#  '31/cd': 0.00245466924675697,
#  'similar/jj': 0.0020788084745471318,
#  'passed/vbd': 0.003288025235864379,
#  '5/cd': 0.01189111063331661,
#  'As/in': 0.0002035857039036545,
#  'word/nn': 0.0015235140256917442,
#  'offered/vbn': 0.0012675593318919192,
#  'pointed/vbd': 0.001663863483790866,
#  'last/ap': 0.049307387862796835,
#  'November/np': 0.0018462113520530577,
#  'rejected/vbd': 0.000436719048890878,
#  'constitutional/jj': 0.0003452741849523493,
#  'amendment/nn': 0.00010133057113702383,
#  'allow/vb': 0.0019702301318733208,
#  'vote/vb': 0.0007335664257046173,
#  'pay/nn': 0.00022577162341056185,
#  'raises/nns': 5.216870348991798e-05,
#  'future/jj': 0.0011475710462524138,
#  'sessions/nns': 0.00045605544018605717,
#  'veteran/jj': 0.00011604651029518792,
#  'Jackson/np': 0.0009117404898647796,
#  'legislator/nn': 4.207292719724381e-05,
#  'ask/vb': 0.00309446986475396,
#  'back/vb': 0.0007054604323826014,
#  'aid/nn': 0.0006465008953829999,
#  'education/nn': 0.001049452874173504,
#  'something/pn': 0.08811957404952316,
#  'consistently/rb': 0.000504282440410185,
#  'opposed/vbn': 0.0010146796646815614,
#  'past/nn': 0.0005753917226552638,
#  'Barber/np': 0.00010354947391816055,
#  'Commerce/nn': 0.00023762315219851785,
#  'asking/vbg': 0.003266825909793452,
#  'endorse/vb': 0.0001714465592642975,
#  'increased/vbn': 0.003258986711173488,
#  'support/nn': 0.0007294615968986919,
#  'provided/vbn': 0.003132546877568309,
#  'expended/vbn': 0.00031926057985307693,
#  '13th/od': 0.0014650782976270533,
#  'members/nns': 0.005201724596365693,
#  'congressional/jj': 0.00018768015862555084,
#  'delegation/nn': 6.57759847731558e-05,
#  'Washington/np': 0.005205255262081193,
#  'like/vb': 0.005820751216989511,
#  'see/vb': 0.020014277844607586,
#  'passed/vbn': 0.0021210282087268774,
#  'But/cc': 0.03377231533961749,
#  'congressmen/nns': 0.00013631177363494697,
#  'specifically/rb': 0.0009267179925862561,
#  'asked/vbd': 0.010434336944987839,
#  'him/ppo': 0.19367616293379275,
#  'tossed/vbd': 0.0007976438826849922,
#  'formally/rb': 0.0004514779963881761,
#  'read/vbn': 0.001425609123898393,
#  'event/nn': 0.00047465372795763786,
#  'Congress/np': 0.0037909209841746096,
#  'does/doz': 0.16908896198271245,
#  'Board/nn': 0.0004094703196238798,
#  'Education/nn': 0.00023169738780453984,
#  'directed/vbn': 0.0017417087079113405,
#  'give/vb': 0.010402028128478118,
#  'teacher/nn': 0.00046872796356365985,
#  'After/in': 0.0012580136524086378,
#  'long/jj': 0.007193450965335044,
#  'hot/jj': 0.0016776600438970994,
#  'controversy/nn': 0.00015466245068282585,
#  'Miller/np': 0.0005581569203881338,
#  'school/nn': 0.0025308939726680045,
#  'superintendent/nn': 7.762751356111182e-05,
#  'policeman/nn': 0.00010725633553100183,
#  'put/vbd': 0.004695632087661424,
#  'UNK/jjt': 0.06618417605449305,
#  'I/ppss': 0.2981850987051582,
#  'ever/rb': 0.008398546821700515,
#  'saw/vbd': 0.011878036280164294,
#  'Harry/np': 0.0008612285513681159,
#  'Davis/np': 0.000684436766629793,
#  'agriculture/nn': 7.170174916713382e-05,
#  'defeated/vbd': 0.00018407166523499814,
#  'Felix/np': 0.0007602046743747885,
#  'principal/nn': 0.00011318209992497983,
#  'Democratic/jj': 0.0009756502902595429,
#  'received/vbd': 0.002313528184620271,
#  'votes/nns': 0.0002877692998959992,
#  's/nr': 0.019214474405622288,
#  'got/vbd': 0.01180585131340547,
#  'Ordinary/nn': 1.2444105227353803e-05,
#  'Carey/np': 0.0001288054431664924,
#  'armed/vbn': 0.0009830697062802665,
#  'pistol/nn': 0.00016058821507680383,
#  'stood/vbd': 0.006969458540564342,
#  'polls/nns': 0.00015314038766395277,
#  'insure/vb': 0.0006773544390605853,
#  'order/nn': 0.0020449812923618083,
#  'Tom/np': 0.0015936516595697395,
#  'Being/beg': 0.0062853782253914576,
#  'just/rb': 0.017375302305442028,
#  'like/cs': 0.039211510839429475,
#  'church/nn': 0.001310186507508536,
#  't/dod': 0.1146919156821867,
#  'smell/vb': 0.0002557645392303455,
#  'drop/nn': 0.00014281092189486982,
#  'liquor/nn': 0.00026132620977442985,
#  'bit/nn': 0.0005516886650793519,
#  'trouble/nn': 0.0007353873612926699,
#  'leading/vbg': 0.003266825909793452,
#  'so/ql': 0.08206706837830757,
#  'quiet/jj': 0.0008896899122631074,
#  'marked/vbn': 0.002152638167128172,
#  'anonymous/jj': 0.0002449870772898412,
#  'midnight/nn': 0.00011910786431895783,
#  'phone/nn': 0.00027910350295636384,
#  'calls/nns': 0.0003719123700410282,
#  'veiled/vbn': 0.00019282074624789794,
#  'threats/nns': 0.00023728345780898178,
#  'violence/nn': 0.0002731777385623858,
#  'former/ap': 0.011118247465629772,
#  'George/np': 0.003260545629959641,
#  'shot/vbd': 0.0006532739491673465,
#  'himself/ppl': 0.17874470306454585,
#  'death/nn': 0.0015590686120556122,
#  'March/np': 0.0023260747677713626,
#  '18/cd': 0.003469982560500729,
#  'four/cd': 0.02120810339472993,
#  'days/nns': 0.006278755894222064,
#  'post/nn': 0.0003442869112901219,
#  'dispute/nn': 0.00017836550825873785,
#  'board/nn': 0.0009664921726578119,
#  'During/in': 0.0010714610153654484,
#  'reportedly/rb': 0.00024026022030014047,
#  'telephone/nn': 0.00037391573326001185,
#  'too/rb': 0.007316055719249333,
#  'subjected/vbn': 0.0007617999974712034,
#  'soon/rb': 0.004596626852115874,
#  'scheduled/vbd': 7.579421509676395e-05,
#  'Many/ap': 0.008601235939452853,
#  'local/jj': 0.00384099622347406,
#  'feared/vbd': 0.0003645340821320552,
#  'permit/nn': 5.985022037917781e-05,
#  'carry/vb': 0.0023918200317035606,
#  'gun/nn': 0.0005872432514432199,
#  'promised/vbd': 0.0009059213328232263,
#  'Sheriff/nn': 3.0221398409287804e-05,
#  'ordinary/nn': 6.5183408333758015e-06,
#  'made/vbd': 0.016533966636108365,
#  'good/jj': 0.009757935575562038,
#  'promise/nn': 0.00021392009462260585,
#  'Everything/pn': 0.0049394859513321645,
#  'went/vbd': 0.017905481004526,
#  'real/ql': 0.0013192859014184662,
#  'smooth/jj': 0.0005171949409452203,
#  'sheriff/nn': 8.947904234906782e-05,
#  'There/ex': 0.1859351644245142,
#  't/bedz': 0.012708922493353427,
#  'Austin/np': 0.00045713304339480644,
#  'approval/nn': 0.00030280656053227584,
#  'Price/np': 0.00010354947391816055,
#  'abandoned/vbn': 0.0006353601638660244,
#  'seemed/vbd': 0.011084001645817243,
#  'certain/jj': 0.00306735282150614,
#  'Thursday/nr': 0.0082490156008573,
#  'despite/in': 0.0005280250726744186,
#  'adamant/jj': 7.306632129697017e-05,
#  'protests/nns': 0.00010265454557693536,
#  'bankers/nns': 0.00018679761572196437,
#  'Daniel/np': 0.0003813651356498108,
#  'personally/rb': 0.0009267179925862561,
#  'led/vbd': 0.002927100402070265,
#  'fight/nn': 0.00033243538250216586,
#  'measure/nn': 0.00035613844007807786,
#  'watered/vbn': 9.799087104401371e-05,
#  'down/rp': 0.08558434399117971,
#  'considerably/rb': 0.0005570868844321939,
#  'rejection/nn': 7.170174916713382e-05,
#  'hearing/nn': 0.00028502926735034185,
#  'before/in': 0.0030910960859634553,
#  'Revenue/nn': 9.540480674304583e-05,
#  'Under/in': 0.00045502621470099665,
#  'rules/nns': 0.0012301716855203238,
#  'automatically/rb': 0.0008739135485642472,
#  'week/nn': 0.0015294397900857222,
#  'questions/nns': 0.0022062312992026604,
#  'UNK/vbd': 0.05677708560415208,
#  'appearing/vbg': 0.0008079246873682733,
#  'witnesses/nns': 0.0003214265279540108,
#  'left/vbd': 0.005561851688767297,
#  'little/ap': 0.033163796694903484,
#  'doubt/nn': 0.0005635401938673079,
#  'recommend/vb': 0.0006773544390605853,
#  'passage/nn': 0.00028502926735034185,
#  'termed/vbd': 0.00011188669847617536,
#  'extremely/rb': 5.544466622310934e-05,
#  'conservative/jj': 0.00043123456294878477,
#  'estimate/nn': 0.00014873668628884783,
#  'produce/vb': 0.0020826541051613846,
#  '17/cd': 0.0026935664970496194,
#  'dollars/nns': 0.001634058422216463,
#  'help/vb': 0.005680221250379431,
#  'anticipated/vbn': 0.000572140247063435,
#  'deficit/nn': 7.170174916713382e-05,
#  '63/cd': 0.0003643183066962899,
#  'current/jj': 0.001176224505584559,
#  'fiscal/jj': 0.001663333314231027,
#  'merely/rb': 0.003355722417598665,
#  'means/nns': 0.0018864876326515501,
#  'books/nns': 0.0015667439661004399,
#  'republic/nn': 4.799869159122181e-05,
#  'permits/vbz': 0.0026452795986763064,
#  'over/rp': 0.04712087801944472,
#  'bank/nn': 0.0003205838537142099,
#  'accounts/nns': 0.00045605544018605717,
#  'stocks/nns': 0.0002877692998959992,
#  'personal/jj': 0.0027521647688525433,
#  'persons/nns': 0.001970630702796579,
#  'missing/vbg': 0.0015606495513759812,
#  'seven/cd': 0.006038128001146707,
#  'bill/nn': 0.00046280219916968184,
#  'banks/nns': 0.0003214265279540108,
#  'insurance/nn': 0.0002494746809864738,
#  'firms/nns': 0.0009272566329982196,
#  'companies/nns': 0.0014489436678973993,
#  'corporations/nns': 0.00035508375601202237,
#  'report/vb': 0.0010427323522467931,
#  'treasurer/nn': 8.947904234906782e-05,
#  'cannot/md': 0.016936089482629146,
#  'enforced/vbn': 0.0006037502054647297,
#  'now/rb': 0.02709132000549166,
#  'because/cs': 0.027436783912883726,
#  'almost/rb': 0.006576793502941208,
#  'impossible/jj': 0.0011618977759184864,
#  'locate/vb': 0.0003962945058404254,
#  'declared/vbd': 0.0019165108674467457,
#  'Lawrence/np': 0.0009875083976097752,
#  'lawyer/nn': 0.00025540044538045184,
#  'representing/vbg': 0.0014101045785744396,
#  'sounded/vbd': 0.0010141987829614606,
#  'opposition/nn': 0.00026725197416840787,
#  'violate/vb': 0.00019955255258631352,
#  'their/pp': 0.1336560177282029,
#  'contractual/jj': 0.00010171978062911534,
#  'obligations/nns': 0.00035508375601202237,
#  'undermine/vb': 0.0002276585459083295,
#  'confidence/nn': 0.00035021267568409984,
#  'customers/nns': 0.0006579988085341268,
#  'If/cs': 0.030025553662691655,
#  'you/ppss': 0.10720182079766033,
#  'destroy/vb': 0.0013518982787889692,
#  'economy/nn': 0.00044502490598774785,
#  'You/ppss': 0.029664614731479518,
#  'circulation/nn': 9.540480674304583e-05,
#  'millions/nns': 0.000809456334795179,
#  'Charles/np': 0.00242709864476469,
#  'Hughes/np': 0.0007602046743747885,
#  'Sherman/np': 0.0007349487051264567,
#  'sponsor/nn': 4.799869159122181e-05,
#  'failure/nn': 0.0005042825499275279,
#  'enact/vb': 0.00019955255258631352,
#  'amount/vb': 0.0007897784123486492,
#  'gift/nn': 0.00019614280144067184,
#  'pockets/nns': 0.000304597913925005,
#  'contention/nn': 5.392445598519981e-05,
#  'denied/vbn': 0.001172729456688035,
#  'several/ap': 0.028824121649770867,
#  'including/in': 0.0013391234946013289,
#  'Scott/np': 0.0004066211048981427,
#  'Hudson/np': 0.001315835997838089,
#  'Jones/np': 0.0018462113520530577,
#  'Houston/np': 0.0006339248281331294,
#  'Howard/np': 0.0008107166128714522,
#  'Cox/np': 0.0001288054431664924,
#  'argued/vbd': 0.0006171814657879351,
#  'probably/rb': 0.006180760172776141,
#  'since/cs': 0.011403113204395899,
#  'complained/vbd': 0.0007615513993055807,
#  'enough/ap': 0.015023955006249132,
#  'introduced/vbn': 0.001172729456688035,
#  'only/rb': 0.03292621106992365,
#  'Senators/nns': 8.582593154792957e-05,
#  'unanimously/rb': 0.0002666624423111449,
#  'Parkhouse/np': 0.0001288054431664924,
#  'Dallas/np': 0.0015178837518247438,
#  'authorizing/vbg': 0.0002559264537626207,
#  'schools/nns': 0.0031991195269140023,
#  'deaf/jj': 0.00015902669929340567,
#  'designed/vbn': 0.0030693269607657194,
#  'special/jj': 0.0032822537664972287,
#  'schooling/nn': 1.8369869621331803e-05,
#  'students/nns': 0.003417891509291078,
#  'scholastic/jj': 0.0001303732399612605,
#  'reduced/vbn': 0.0021210282087268774,
#  'debate/nn': 0.00015466245068282585,
#  'authorize/vb': 0.00014334056594228153,
#  'Agency/nn': 4.799869159122181e-05,
#  'establish/vb': 0.001661064205331145,
#  'wide/jj': 0.0020501550152149865,
#  '000/cd': 0.013145321197353019,
#  'population/nn': 0.0008064965340204059,
#  'require/vb': 0.0023637140383815443,
#  'children/nns': 0.005706583017235867,
#  'between/in': 0.005719054973006644,
#  '6/cd': 0.00824792756635371,
#  'attend/vb': 0.001520534238721065,
#  'permitting/vbg': 0.00045665308416467616,
#  'older/jjr': 0.022686522562008166,
#  'residential/jj': 0.0005888285892755832,
#  'School/nn': 0.00043909914159376984,
#  'here/rb': 0.015711962318748746,
#  'Operating/vbg': 0.00030610811136313457,
#  'budget/nn': 0.00033243538250216586,
#  'five/cd': 0.01804271482835233,
#  'Harris/np': 0.0007349487051264567,
#  'El/np': 0.00045713304339480644,
#  'Paso/np': 0.00025508528940815163,
#  '500/nns': 0.0004223982121280456,
#  'savings/nns': 0.0002877692998959992,
#  'yearly/rb': 0.00016105355426712713,
#  'after/in': 0.004340187655730897,
#  'capital/nn': 0.00046280219916968184,
#  '000/nns': 0.002576460807840788,
#  'absorbed/vbn': 0.0006985800806686139,
#  'estimated/vbd': 0.00029234911537323236,
#  'saving/vbg': 0.000908288002569301,
#  'coming/vbg': 0.007983901724241755,
#  'live/vb': 0.004162497610990567,
#  'get/vb': 0.019873747877997505,
#  'hear/vb': 0.004190603604312584,
#  'horse/nn': 0.0006702039529589118,
#  'Red/np': 0.0005329009511398019,
#  'Joe/np': 0.0013916039055830846,
#  'still/rb': 0.017612922303541067,
#  'expects/vbz': 0.0023291107223404927,
#  'tell/vb': 0.006663931016649991,
#  'folks/nns': 0.000304597913925005,
#  'why/wrb': 0.03630901549347322,
#  'thinks/vbz': 0.002434500347785764,
#  'rejected/vbn': 0.0006353601638660244,
#  're/ppss': 0.016220901436354632,
#  'pro/jj': 5.873959163089759e-05,
#  'letters/nns': 0.0018528304045935383,
#  'con/jj': 3.0086132298752428e-05,
#  'believe/vb': 0.005427267310481287,
#  'if/cs': 0.06050622974913986,
#  'people/nns': 0.013296287944317482,
#  'better/rbr': 0.04833883936919528,
#  'informed/vbn': 0.0010146796646815614,
#  'question/nn': 0.001363518387054338,
#  'most/ap': 0.032816622691292874,
#  'oppose/vb': 0.00042440049916244143,
#  'm/ppss': 0.015159555649897407,
#  'willing/jj': 0.0009899770199256154,
#  'stake/vb': 3.091659265421759e-05,
#  'my/pp': 0.05996522218570081,
#  'San/np': 0.0017704434443080621,
#  'Antonio/np': 0.00015406141241482423,
#  'ponies/nns': 0.00010265454557693536,
#  'heard/vbd': 0.004551262154143778,
#  'option/nn': 3.0221398409287804e-05,
#  'proposal/nn': 0.00023762315219851785,
#  'favorable/jj': 0.00047421475194700253,
#  'report/nn': 0.0006820554817468679,
#  'although/cs': 0.00814627384173431,
#  'faces/vbz': 0.001275214467887781,
#  'hard/jj': 0.001978521366884624,
#  'later/rbr': 0.09290656361029732,
#  'house/nn': 0.0023531210408486644,
#  'finally/rb': 0.003461331305642683,
#  'sent/vbd': 0.0024578981181379166,
#  'extending/vbg': 0.0014101045785744396,
#  'authority/nn': 0.0004924310211395719,
#  'planning/vbg': 0.0035679158553965354,
#  'cities/nns': 0.0017855159484775152,
#  'senate/nn': 3.0221398409287804e-05,
#  'quickly/rb': 0.002299633537158487,
#  'whipped/vbd': 0.00025625663199382095,
#  'meager/jj': 7.306632129697017e-05,
#  'fare/nn': 4.207292719724381e-05,
#  'bills/nns': 0.0007589704927081616,
#  'committees/nns': 0.00023728345780898178,
#  ...}

# %% [markdown]
# ## 4.4
#
# Generate 5 random sentences using HMM. Output each sentence (with the POS tags) and
# its probability of being generated.

# %%
## generate five random sentences based on emission and transition probability starting and ending with <START> and <END> yag 
list_5_rand_sentences = []
while (len(list_5_rand_sentences) != 5):
    prev_tag = "<START>"
    tag_drawn = " "
    rand_sententence = []
    while True:
        next_set_of_tags = [i for i in bigram_counter_tag if i.split(" ")[0] == prev_tag and i != "<END> <START>"]
        prob_next_tag = [prob_transition[i] for i in next_set_of_tags]
        tag_drawn = random.choices(next_set_of_tags,prob_next_tag)
        prev_tag = tag_drawn[0].split(" ")[1]
        if prev_tag == "<END>":
            break
        probable_words = [i for i in counter_word_tag if i not in ["<END>","<START>"] and i.split("/")[1] == prev_tag and "UNK" not in i]
        word_probabilities = [prob_emission[i] for i in probable_words]
        word_drawn = random.choices(probable_words,word_probabilities)
        prob_of_this_word = prob_emission[word_drawn[0]] * prob_transition[tag_drawn[0]]
        word_drawn[0] = word_drawn[0] + " " + str(prob_of_this_word)
        rand_sententence.extend(word_drawn)
    list_5_rand_sentences.append(" ".join(rand_sententence))

# %%
## print the sentences
for index, i in enumerate(list_5_rand_sentences):
    print ("Sentence ID:", index+1, "\n\t", i, "\n")
    sentence = i.split(" ")
    sent_list = [j.split("/")[0] for j in sentence if "/" in j]
    sent_str = " ".join(sent_list)
    print ("**Printing the sentence properly**\n\t",sent_str, "\n")
# Out:
# Sentence ID: 1
# 	 John/np 0.0007098881965105562 William/np 0.0007291966409498122 of/in 0.018772209734886754 the/at 0.22266728573686068 grounds/nns 6.915242320338724e-05 of/in 0.07908709712941428 all/abn 0.00434994068179207 be/be 0.001543369745140279 with/in 0.002340103095761513 both/abx 0.0004348187807154439 The/at 0.007202984273656557 spite/nn 0.00015251024398632337 and/cc 0.05789187326335965 it/pps 0.007095342160281965 was/bedz 0.12110602133238504 implying/vbg 3.072770558043864e-05
#
# **Printing the sentence properly**
# 	 John William of the grounds of all be with both The spite and it was implying
#
# Sentence ID: 2
# 	 who/wps 0.0005389002024534835 get/vb 0.0021519696210883033 his/pp 0.01681628796631599 British/jj 0.0002648576310265283 to/to 0.016668149746310208 understand/vb 0.0030966175475128834 Hanover/np 3.354784438502727e-05
#
# **Printing the sentence properly**
# 	 who get his British to understand Hanover
#
# Sentence ID: 3
# 	 shaking/vbg 1.1680090182855517e-05 to/in 0.014613290979083142 an/at 0.012544165832738008 fault/nn 7.007227426398642e-05 Af/nn 0.0006134999614596458 in/in 0.04259250616386392 my/pp 0.003775854381929988 underlying/vbg 1.22435097533252e-05 the/at 0.08751171742724961 bit/nn 0.0002951913454288296 started/vbd 0.00012961388976376881 in/in 0.0264836077185481 the/at 0.22266728573686068 scientific/jj 0.0002568684921572241 existence/nn 0.0002940056162127484
#
# **Printing the sentence properly**
# 	 shaking to an fault Af in my underlying the bit started in the scientific existence
#
# Sentence ID: 4
# 	 batch/nn 1.2309915162205632e-06 with/in 0.015622572262068908 his/pp 0.021268098181163597 countries/nns 0.00048136309436081875
#
# **Printing the sentence properly**
# 	 batch with his countries
#
# Sentence ID: 5
# 	 this/dt 0.012057133216562493 will/nn 0.00029922984169964355 as/cs 0.0063515204078663755 the/at 0.1608102470389059 fair/jj 0.00018577372296810072 Supreme/jj 2.8185444401170853e-05 interview/nn 8.458440947471301e-05 with/in 0.015622572262068908 some/dti 0.0025107336782454366 symbol/nn 0.00013181722758083935
#
# **Printing the sentence properly**
# 	 this will as the fair Supreme interview with some symbol

# %%
## get the test dataset and format it
def collect_testdata(filename): 
    with open(filename) as file:
        file_content = file.read()
    file_content = file_content.split("<EOS>")
    file_dict = {}
    for index, content in enumerate(file_content):
        list_content = content.split("\n")
        list_content = [i for i in list_content if re.match("\w+", i)]
        file_dict[index] = list_content
    return file_dict

filename = r"C:\Users\mm199\NLP\HW1\science_sample.txt"
file_dict = collect_testdata(filename)

# %% [markdown]
# ## 4.5
# For each word in the test dataset, derive the most probable tag sequence using the Viterbi al-
# gorithm; pseudo-code can be found in the textbook https://web.stanford.edu/~jurafsky/
# slp3/ed3book.pdf under Figure 8.5. For each word, output the tag derived using the
# Viterbi algorithm in the following format(where each line contains no more than one pair):
# <sentence ID=1>
# word, tag
# word, tag
# :::
# word, tag
# <EOS>
# <sentence ID=2>
# word, tag
# word, tag
# :::
# word, tag
# <EOS>
#
# Submit your code, a README.txt file explaining how to run your code. Please also
# include your output file with the tag predictions in the format specified above.

# %%
## viterbi algorithm by just considering previous state
def viterbi_algo(test_data, counter_tag, prob_transition, prob_emission, smoothed_prob_transition, smoothed_prob_emission):
    len_of_test_data = len(test_data)
    total_unique_tags = [i for i in counter_tag if i not in ["<START>", "<END>"]]
    len_of_total_tags = len(total_unique_tags)
    pi = np.ndarray((len_of_test_data+1, len_of_total_tags+1))
    bp =  np.ndarray((len_of_test_data, len_of_total_tags))
    pi[0][:] = 1.0
    for i in range(len_of_test_data):
        for index1, tags1 in enumerate(total_unique_tags):
            max_tag_prob = -1
            if i == 0:
                all_tags = ["<START>"]
            else:
                all_tags = total_unique_tags
            for index2, tags2 in enumerate(all_tags):
                transition = tags2 + " " + tags1
                emission = test_data[i] + "/" + tags1
                if transition not in prob_transition or prob_transition[transition] == 0:
                    prob_transition[transition] = smoothed_prob_transition[tags2]
                else:
                    pass
                if emission not in prob_emission or prob_emission[emission] == 0:
                    prob_emission[emission] = smoothed_prob_emission[tags1]
                else:
                    pass
                prob = pi[i][index2] * prob_transition[transition] * prob_emission[emission]
                if prob > max_tag_prob:
                    max_tag_prob = prob
                    max_index = index2
            if max_tag_prob == 0:
                print (index1, i, tags1, index2, tags2)
            pi[i+1][index1] = max_tag_prob
            bp[i][index1] = max_index
    ## get the back pointer starting point
    last_array = pi[(len_of_test_data)][1:]
    for i, tags in enumerate(total_unique_tags):
        transition = tags + " " + "<END>"
        if transition not in prob_transition or prob_transition[transition] == 0:
            prob_transition[transition] = smoothed_prob_transition[tags]
        else:
            pass
        last_array[i] = last_array[i] * prob_transition[transition]
    bp_start = np.argmax(last_array)
    ## traverse from the end with the help of back pointer
    index = len_of_test_data - 1
    word_with_tag_result_list = [(test_data[index], total_unique_tags[bp_start])] ## initiate the tuple which contains word and its tag
    pointer = bp_start
    while (index != -1):
        pointer = int (bp[index][pointer])
        if index != 0:
            tuple_to_be_added = (test_data[index-1], total_unique_tags[pointer])
            word_with_tag_result_list.append(tuple_to_be_added)
        index -= 1
    return word_with_tag_result_list

# %%
## save the result in a list of list as a tuple format
final_tag_result = []
for i in range(len(file_dict)):
    test_data = file_dict[i]
    if test_data == []:
        break
    word_with_tag_result_list = viterbi_algo(test_data, counter_tag, prob_transition, prob_emission, smoothed_prob_transition, smoothed_prob_emission)
    final_tag_result.append(word_with_tag_result_list)

# %%
## write the output on a file
with open("output.txt", "w") as file:
    for index, each_sentence in enumerate(final_tag_result):
        start = "<sentence ID=%s>\n"%(index+1)
        file.write(start)
        for word,tag in each_sentence[::-1]:
            word_and_its_tag = (word + ", " + tag + "\n")
            file.write(word_and_its_tag)
        end = "<EOS>\n\n"
        file.write(end)
